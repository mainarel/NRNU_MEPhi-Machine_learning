# %% [markdown]
# ## 3. Библиотека requests

# %%
import requests

# %% [markdown]
# Как только библиотека установлена, импортируем её и отправим наш первый запрос к ресурсу Курсы валют ЦБ РФ в XML и JSON. Используем метод get() из библиотеки requests, передав ему соответствующий URL — https://www.cbr-xml-daily.ru/daily_json.js:>

# %%
url = "https://www.cbr-xml-daily.ru/daily_json.js"  # Определяем значение URL страницы для запроса
response = requests.get(
    url
)  # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response

# %% [markdown]
# Проверим ответ сервера — содержимое переменной response:

# %%
print(response)  # Выводим значение response на экран как объект
# Out:
# <Response [200]>

# %% [markdown]
# Мы получили объект ответа Response, который содержит всю нужную нам информацию. По умолчанию в квадратных скобках на экран выводится код статуса ответа. В данном случае он равен 200 — то есть запрос был корректным и сервер отдал нам нужную информацию. Значение кода статуса 404 означало бы, что страница по указанному адресу не найдена, а значение 403 — что синтаксис GET - запроса неверный.

# %% [markdown]
# Код ответа в виде числовой переменной можно получить с помощью метода status_code:

# %%
print(response.status_code)  # Выводим числовое значение response на экран
# Out:
# 200

# %% [markdown]
# ### Задание 3.1
#
# Вы уже импортировали модуль requests в ваш код. Напишите строку кода, при выполнении которой будет сделан GET-запрос к ресурсу https://www.cbr-xml-daily.ru/daily.xml, а результат ответа будет сохранён в переменной response:

# %%
response = requests.get("https://www.cbr-xml-daily.ru/daily.xml")
response
# Out:
# <Response [200]>

# %% [markdown]
# Мы сделали запрос и получили корректный ответ (код статуса — 200). Дальнейшую работу производим с результатом запроса к ресурсу Курсы валют ЦБ РФ вXML и JSON.

# %% [markdown]
# ### Как получить доступ ко всей информации, которую содержит ответ?
# Текст ответа хранится в атрибуте text. Выведем значение атрибута на экран и посмотрим на его содержимое:

# %%
print(response.text)  # Выводим содержимое атрибута text переменной response на экран
# Out:
# {
#     "Date": "2024-11-26T11:30:00+03:00",
#     "PreviousDate": "2024-11-23T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2024\/11\/23\/daily_json.js",
#     "Timestamp": "2024-11-25T20:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 67.7235,
#             "Previous": 66.7155
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 61.0534,
#             "Previous": 60.3389
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов Соединенного королевства",
#             "Value": 130.0187,
#             "Previous": 129.4305
#         },
#         "AMD": {
#             "ID": "R01060",
#             "NumCode": "051",
#             "CharCode": "AMD",
#             "Nominal": 100,
#             "Name": "Армянских драмов",
#             "Value": 26.6035,
#             "Previous": 26.3178
#         },
#         "BYN": {
#             "ID": "R01090B",
#             "NumCode": "933",
#             "CharCode": "BYN",
#             "Nominal": 1,
#             "Name": "Белорусский рубль",
#             "Value": 29.9264,
#             "Previous": 29.9317
#         },
#         "BGN": {
#             "ID": "R01100",
#             "NumCode": "975",
#             "CharCode": "BGN",
#             "Nominal": 1,
#             "Name": "Болгарский лев",
#             "Value": 55.2537,
#             "Previous": 55.2051
#         },
#         "BRL": {
#             "ID": "R01115",
#             "NumCode": "986",
#             "CharCode": "BRL",
#             "Nominal": 1,
#             "Name": "Бразильский реал",
#             "Value": 17.8577,
#             "Previous": 17.6338
#         },
#         "HUF": {
#             "ID": "R01135",
#             "NumCode": "348",
#             "CharCode": "HUF",
#             "Nominal": 100,
#             "Name": "Венгерских форинтов",
#             "Value": 26.4348,
#             "Previous": 25.9476
#         },
#         "VND": {
#             "ID": "R01150",
#             "NumCode": "704",
#             "CharCode": "VND",
#             "Nominal": 10000,
#             "Name": "Вьетнамских донгов",
#             "Value": 42.7263,
#             "Previous": 42.2211
#         },
#         "HKD": {
#             "ID": "R01200",
#             "NumCode": "344",
#             "CharCode": "HKD",
#             "Nominal": 1,
#             "Name": "Гонконгский доллар",
#             "Value": 13.363,
#             "Previous": 13.1999
#         },
#         "GEL": {
#             "ID": "R01210",
#             "NumCode": "981",
#             "CharCode": "GEL",
#             "Nominal": 1,
#             "Name": "Грузинский лари",
#             "Value": 37.902,
#             "Previous": 37.3915
#         },
#         "DKK": {
#             "ID": "R01215",
#             "NumCode": "208",
#             "CharCode": "DKK",
#             "Nominal": 1,
#             "Name": "Датская крона",
#             "Value": 14.4907,
#             "Previous": 14.4757
#         },
#         "AED": {
#             "ID": "R01230",
#             "NumCode": "784",
#             "CharCode": "AED",
#             "Nominal": 1,
#             "Name": "Дирхам ОАЭ",
#             "Value": 28.2616,
#             "Previous": 27.9309
#         },
#         "USD": {
#             "ID": "R01235",
#             "NumCode": "840",
#             "CharCode": "USD",
#             "Nominal": 1,
#             "Name": "Доллар США",
#             "Value": 103.7908,
#             "Previous": 102.5761
#         },
#         "EUR": {
#             "ID": "R01239",
#             "NumCode": "978",
#             "CharCode": "EUR",
#             "Nominal": 1,
#             "Name": "Евро",
#             "Value": 108.8705,
#             "Previous": 107.4252
#         },
#         "EGP": {
#             "ID": "R01240",
#             "NumCode": "818",
#             "CharCode": "EGP",
#             "Nominal": 10,
#             "Name": "Египетских фунтов",
#             "Value": 20.9183,
#             "Previous": 20.6493
#         },
#         "INR": {
#             "ID": "R01270",
#             "NumCode": "356",
#             "CharCode": "INR",
#             "Nominal": 10,
#             "Name": "Индийских рупий",
#             "Value": 12.3153,
#             "Previous": 12.1395
#         },
#         "IDR": {
#             "ID": "R01280",
#             "NumCode": "360",
#             "CharCode": "IDR",
#             "Nominal": 10000,
#             "Name": "Индонезийских рупий",
#             "Value": 65.2321,
#             "Previous": 64.3433
#         },
#         "KZT": {
#             "ID": "R01335",
#             "NumCode": "398",
#             "CharCode": "KZT",
#             "Nominal": 100,
#             "Name": "Казахстанских тенге",
#             "Value": 20.8273,
#             "Previous": 20.7279
#         },
#         "CAD": {
#             "ID": "R01350",
#             "NumCode": "124",
#             "CharCode": "CAD",
#             "Nominal": 1,
#             "Name": "Канадский доллар",
#             "Value": 74.2477,
#             "Previous": 73.4786
#         },
#         "QAR": {
#             "ID": "R01355",
#             "NumCode": "634",
#             "CharCode": "QAR",
#             "Nominal": 1,
#             "Name": "Катарский риал",
#             "Value": 28.514,
#             "Previous": 28.1802
#         },
#         "KGS": {
#             "ID": "R01370",
#             "NumCode": "417",
#             "CharCode": "KGS",
#             "Nominal": 10,
#             "Name": "Киргизских сомов",
#             "Value": 11.9589,
#             "Previous": 11.8585
#         },
#         "CNY": {
#             "ID": "R01375",
#             "NumCode": "156",
#             "CharCode": "CNY",
#             "Nominal": 1,
#             "Name": "Китайский юань",
#             "Value": 14.2057,
#             "Previous": 13.9427
#         },
#         "MDL": {
#             "ID": "R01500",
#             "NumCode": "498",
#             "CharCode": "MDL",
#             "Nominal": 10,
#             "Name": "Молдавских леев",
#             "Value": 56.9384,
#             "Previous": 56.3348
#         },
#         "NZD": {
#             "ID": "R01530",
#             "NumCode": "554",
#             "CharCode": "NZD",
#             "Nominal": 1,
#             "Name": "Новозеландский доллар",
#             "Value": 60.8525,
#             "Previous": 60.0429
#         },
#         "NOK": {
#             "ID": "R01535",
#             "NumCode": "578",
#             "CharCode": "NOK",
#             "Nominal": 10,
#             "Name": "Норвежских крон",
#             "Value": 93.4185,
#             "Previous": 92.919
#         },
#         "PLN": {
#             "ID": "R01565",
#             "NumCode": "985",
#             "CharCode": "PLN",
#             "Nominal": 1,
#             "Name": "Польский злотый",
#             "Value": 25.1328,
#             "Previous": 24.5679
#         },
#         "RON": {
#             "ID": "R01585F",
#             "NumCode": "946",
#             "CharCode": "RON",
#             "Nominal": 1,
#             "Name": "Румынский лей",
#             "Value": 21.871,
#             "Previous": 21.4855
#         },
#         "XDR": {
#             "ID": "R01589",
#             "NumCode": "960",
#             "CharCode": "XDR",
#             "Nominal": 1,
#             "Name": "СДР (специальные права заимствования)",
#             "Value": 135.6816,
#             "Previous": 134.6127
#         },
#         "SGD": {
#             "ID": "R01625",
#             "NumCode": "702",
#             "CharCode": "SGD",
#             "Nominal": 1,
#             "Name": "Сингапурский доллар",
#             "Value": 77.2655,
#             "Previous": 76.2364
#         },
#         "TJS": {
#             "ID": "R01670",
#             "NumCode": "972",
#             "CharCode": "TJS",
#             "Nominal": 10,
#             "Name": "Таджикских сомони",
#             "Value": 97.2771,
#             "Previous": 96.1612
#         },
#         "THB": {
#             "ID": "R01675",
#             "NumCode": "764",
#             "CharCode": "THB",
#             "Nominal": 10,
#             "Name": "Таиландских батов",
#             "Value": 30.0756,
#             "Previous": 29.5259
#         },
#         "TRY": {
#             "ID": "R01700J",
#             "NumCode": "949",
#             "CharCode": "TRY",
#             "Nominal": 10,
#             "Name": "Турецких лир",
#             "Value": 30.0884,
#             "Previous": 29.749
#         },
#         "TMT": {
#             "ID": "R01710A",
#             "NumCode": "934",
#             "CharCode": "TMT",
#             "Nominal": 1,
#             "Name": "Новый туркменский манат",
#             "Value": 29.6545,
#             "Previous": 29.3075
#         },
#         "UZS": {
#             "ID": "R01717",
#             "NumCode": "860",
#             "CharCode": "UZS",
#             "Nominal": 10000,
#             "Name": "Узбекских сумов",
#             "Value": 80.9028,
#             "Previous": 79.8617
#         },
#         "UAH": {
#             "ID": "R01720",
#             "NumCode": "980",
#             "CharCode": "UAH",
#             "Nominal": 10,
#             "Name": "Украинских гривен",
#             "Value": 25.1192,
#             "Previous": 24.8453
#         },
#         "CZK": {
#             "ID": "R01760",
#             "NumCode": "203",
#             "CharCode": "CZK",
#             "Nominal": 10,
#             "Name": "Чешских крон",
#             "Value": 42.6473,
#             "Previous": 42.6388
#         },
#         "SEK": {
#             "ID": "R01770",
#             "NumCode": "752",
#             "CharCode": "SEK",
#             "Nominal": 10,
#             "Name": "Шведских крон",
#             "Value": 93.5402,
#             "Previous": 93.0228
#         },
#         "CHF": {
#             "ID": "R01775",
#             "NumCode": "756",
#             "CharCode": "CHF",
#             "Nominal": 1,
#             "Name": "Швейцарский франк",
#             "Value": 116.7763,
#             "Previous": 115.4097
#         },
#         "RSD": {
#             "ID": "R01805F",
#             "NumCode": "941",
#             "CharCode": "RSD",
#             "Nominal": 100,
#             "Name": "Сербских динаров",
#             "Value": 92.9433,
#             "Previous": 91.7942
#         },
#         "ZAR": {
#             "ID": "R01810",
#             "NumCode": "710",
#             "CharCode": "ZAR",
#             "Nominal": 10,
#             "Name": "Южноафриканских рэндов",
#             "Value": 57.3366,
#             "Previous": 56.8963
#         },
#         "KRW": {
#             "ID": "R01815",
#             "NumCode": "410",
#             "CharCode": "KRW",
#             "Nominal": 1000,
#             "Name": "Вон Республики Корея",
#             "Value": 74.1098,
#             "Previous": 73.3682
#         },
#         "JPY": {
#             "ID": "R01820",
#             "NumCode": "392",
#             "CharCode": "JPY",
#             "Nominal": 100,
#             "Name": "Японских иен",
#             "Value": 67.3092,
#             "Previous": 66.4353
#         }
#     }
# }

# %% [markdown]
# Для того чтобы удобно было работать с полученной информацией, нам необходимо преобразовать строку в словарь. В объект ответа Response  из библиотеки requests уже встроен метод json().

# %% [markdown]
# Импортируем функцию pprint(), применим к полученному ответу метод json() и выведем полученный результат на экран:

# %%
from pprint import pprint  # Импортируем функцию pprint()

currencies = response.json()  # Применяем метод json()
pprint(currencies)  # Выводим результат на экран)
# Out:
# {'Date': '2024-11-26T11:30:00+03:00',
#  'PreviousDate': '2024-11-23T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2024/11/23/daily_json.js',
#  'Timestamp': '2024-11-25T20:00:00+03:00',
#  'Valute': {'AED': {'CharCode': 'AED',
#                     'ID': 'R01230',
#                     'Name': 'Дирхам ОАЭ',
#                     'Nominal': 1,
#                     'NumCode': '784',
#                     'Previous': 27.9309,
#                     'Value': 28.2616},
#             'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 26.3178,
#                     'Value': 26.6035},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 66.7155,
#                     'Value': 67.7235},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
#                     'NumCode': '944',
#                     'Previous': 60.3389,
#                     'Value': 61.0534},
#             'BGN': {'CharCode': 'BGN',
#                     'ID': 'R01100',
#                     'Name': 'Болгарский лев',
#                     'Nominal': 1,
#                     'NumCode': '975',
#                     'Previous': 55.2051,
#                     'Value': 55.2537},
#             'BRL': {'CharCode': 'BRL',
#                     'ID': 'R01115',
#                     'Name': 'Бразильский реал',
#                     'Nominal': 1,
#                     'NumCode': '986',
#                     'Previous': 17.6338,
#                     'Value': 17.8577},
#             'BYN': {'CharCode': 'BYN',
#                     'ID': 'R01090B',
#                     'Name': 'Белорусский рубль',
#                     'Nominal': 1,
#                     'NumCode': '933',
#                     'Previous': 29.9317,
#                     'Value': 29.9264},
#             'CAD': {'CharCode': 'CAD',
#                     'ID': 'R01350',
#                     'Name': 'Канадский доллар',
#                     'Nominal': 1,
#                     'NumCode': '124',
#                     'Previous': 73.4786,
#                     'Value': 74.2477},
#             'CHF': {'CharCode': 'CHF',
#                     'ID': 'R01775',
#                     'Name': 'Швейцарский франк',
#                     'Nominal': 1,
#                     'NumCode': '756',
#                     'Previous': 115.4097,
#                     'Value': 116.7763},
#             'CNY': {'CharCode': 'CNY',
#                     'ID': 'R01375',
#                     'Name': 'Китайский юань',
#                     'Nominal': 1,
#                     'NumCode': '156',
#                     'Previous': 13.9427,
#                     'Value': 14.2057},
#             'CZK': {'CharCode': 'CZK',
#                     'ID': 'R01760',
#                     'Name': 'Чешских крон',
#                     'Nominal': 10,
#                     'NumCode': '203',
#                     'Previous': 42.6388,
#                     'Value': 42.6473},
#             'DKK': {'CharCode': 'DKK',
#                     'ID': 'R01215',
#                     'Name': 'Датская крона',
#                     'Nominal': 1,
#                     'NumCode': '208',
#                     'Previous': 14.4757,
#                     'Value': 14.4907},
#             'EGP': {'CharCode': 'EGP',
#                     'ID': 'R01240',
#                     'Name': 'Египетских фунтов',
#                     'Nominal': 10,
#                     'NumCode': '818',
#                     'Previous': 20.6493,
#                     'Value': 20.9183},
#             'EUR': {'CharCode': 'EUR',
#                     'ID': 'R01239',
#                     'Name': 'Евро',
#                     'Nominal': 1,
#                     'NumCode': '978',
#                     'Previous': 107.4252,
#                     'Value': 108.8705},
#             'GBP': {'CharCode': 'GBP',
#                     'ID': 'R01035',
#                     'Name': 'Фунт стерлингов Соединенного королевства',
#                     'Nominal': 1,
#                     'NumCode': '826',
#                     'Previous': 129.4305,
#                     'Value': 130.0187},
#             'GEL': {'CharCode': 'GEL',
#                     'ID': 'R01210',
#                     'Name': 'Грузинский лари',
#                     'Nominal': 1,
#                     'NumCode': '981',
#                     'Previous': 37.3915,
#                     'Value': 37.902},
#             'HKD': {'CharCode': 'HKD',
#                     'ID': 'R01200',
#                     'Name': 'Гонконгский доллар',
#                     'Nominal': 1,
#                     'NumCode': '344',
#                     'Previous': 13.1999,
#                     'Value': 13.363},
#             'HUF': {'CharCode': 'HUF',
#                     'ID': 'R01135',
#                     'Name': 'Венгерских форинтов',
#                     'Nominal': 100,
#                     'NumCode': '348',
#                     'Previous': 25.9476,
#                     'Value': 26.4348},
#             'IDR': {'CharCode': 'IDR',
#                     'ID': 'R01280',
#                     'Name': 'Индонезийских рупий',
#                     'Nominal': 10000,
#                     'NumCode': '360',
#                     'Previous': 64.3433,
#                     'Value': 65.2321},
#             'INR': {'CharCode': 'INR',
#                     'ID': 'R01270',
#                     'Name': 'Индийских рупий',
#                     'Nominal': 10,
#                     'NumCode': '356',
#                     'Previous': 12.1395,
#                     'Value': 12.3153},
#             'JPY': {'CharCode': 'JPY',
#                     'ID': 'R01820',
#                     'Name': 'Японских иен',
#                     'Nominal': 100,
#                     'NumCode': '392',
#                     'Previous': 66.4353,
#                     'Value': 67.3092},
#             'KGS': {'CharCode': 'KGS',
#                     'ID': 'R01370',
#                     'Name': 'Киргизских сомов',
#                     'Nominal': 10,
#                     'NumCode': '417',
#                     'Previous': 11.8585,
#                     'Value': 11.9589},
#             'KRW': {'CharCode': 'KRW',
#                     'ID': 'R01815',
#                     'Name': 'Вон Республики Корея',
#                     'Nominal': 1000,
#                     'NumCode': '410',
#                     'Previous': 73.3682,
#                     'Value': 74.1098},
#             'KZT': {'CharCode': 'KZT',
#                     'ID': 'R01335',
#                     'Name': 'Казахстанских тенге',
#                     'Nominal': 100,
#                     'NumCode': '398',
#                     'Previous': 20.7279,
#                     'Value': 20.8273},
#             'MDL': {'CharCode': 'MDL',
#                     'ID': 'R01500',
#                     'Name': 'Молдавских леев',
#                     'Nominal': 10,
#                     'NumCode': '498',
#                     'Previous': 56.3348,
#                     'Value': 56.9384},
#             'NOK': {'CharCode': 'NOK',
#                     'ID': 'R01535',
#                     'Name': 'Норвежских крон',
#                     'Nominal': 10,
#                     'NumCode': '578',
#                     'Previous': 92.919,
#                     'Value': 93.4185},
#             'NZD': {'CharCode': 'NZD',
#                     'ID': 'R01530',
#                     'Name': 'Новозеландский доллар',
#                     'Nominal': 1,
#                     'NumCode': '554',
#                     'Previous': 60.0429,
#                     'Value': 60.8525},
#             'PLN': {'CharCode': 'PLN',
#                     'ID': 'R01565',
#                     'Name': 'Польский злотый',
#                     'Nominal': 1,
#                     'NumCode': '985',
#                     'Previous': 24.5679,
#                     'Value': 25.1328},
#             'QAR': {'CharCode': 'QAR',
#                     'ID': 'R01355',
#                     'Name': 'Катарский риал',
#                     'Nominal': 1,
#                     'NumCode': '634',
#                     'Previous': 28.1802,
#                     'Value': 28.514},
#             'RON': {'CharCode': 'RON',
#                     'ID': 'R01585F',
#                     'Name': 'Румынский лей',
#                     'Nominal': 1,
#                     'NumCode': '946',
#                     'Previous': 21.4855,
#                     'Value': 21.871},
#             'RSD': {'CharCode': 'RSD',
#                     'ID': 'R01805F',
#                     'Name': 'Сербских динаров',
#                     'Nominal': 100,
#                     'NumCode': '941',
#                     'Previous': 91.7942,
#                     'Value': 92.9433},
#             'SEK': {'CharCode': 'SEK',
#                     'ID': 'R01770',
#                     'Name': 'Шведских крон',
#                     'Nominal': 10,
#                     'NumCode': '752',
#                     'Previous': 93.0228,
#                     'Value': 93.5402},
#             'SGD': {'CharCode': 'SGD',
#                     'ID': 'R01625',
#                     'Name': 'Сингапурский доллар',
#                     'Nominal': 1,
#                     'NumCode': '702',
#                     'Previous': 76.2364,
#                     'Value': 77.2655},
#             'THB': {'CharCode': 'THB',
#                     'ID': 'R01675',
#                     'Name': 'Таиландских батов',
#                     'Nominal': 10,
#                     'NumCode': '764',
#                     'Previous': 29.5259,
#                     'Value': 30.0756},
#             'TJS': {'CharCode': 'TJS',
#                     'ID': 'R01670',
#                     'Name': 'Таджикских сомони',
#                     'Nominal': 10,
#                     'NumCode': '972',
#                     'Previous': 96.1612,
#                     'Value': 97.2771},
#             'TMT': {'CharCode': 'TMT',
#                     'ID': 'R01710A',
#                     'Name': 'Новый туркменский манат',
#                     'Nominal': 1,
#                     'NumCode': '934',
#                     'Previous': 29.3075,
#                     'Value': 29.6545},
#             'TRY': {'CharCode': 'TRY',
#                     'ID': 'R01700J',
#                     'Name': 'Турецких лир',
#                     'Nominal': 10,
#                     'NumCode': '949',
#                     'Previous': 29.749,
#                     'Value': 30.0884},
#             'UAH': {'CharCode': 'UAH',
#                     'ID': 'R01720',
#                     'Name': 'Украинских гривен',
#                     'Nominal': 10,
#                     'NumCode': '980',
#                     'Previous': 24.8453,
#                     'Value': 25.1192},
#             'USD': {'CharCode': 'USD',
#                     'ID': 'R01235',
#                     'Name': 'Доллар США',
#                     'Nominal': 1,
#                     'NumCode': '840',
#                     'Previous': 102.5761,
#                     'Value': 103.7908},
#             'UZS': {'CharCode': 'UZS',
#                     'ID': 'R01717',
#                     'Name': 'Узбекских сумов',
#                     'Nominal': 10000,
#                     'NumCode': '860',
#                     'Previous': 79.8617,
#                     'Value': 80.9028},
#             'VND': {'CharCode': 'VND',
#                     'ID': 'R01150',
#                     'Name': 'Вьетнамских донгов',
#                     'Nominal': 10000,
#                     'NumCode': '704',
#                     'Previous': 42.2211,
#                     'Value': 42.7263},
#             'XDR': {'CharCode': 'XDR',
#                     'ID': 'R01589',
#                     'Name': 'СДР (специальные права заимствования)',
#                     'Nominal': 1,
#                     'NumCode': '960',
#                     'Previous': 134.6127,
#                     'Value': 135.6816},
#             'ZAR': {'CharCode': 'ZAR',
#                     'ID': 'R01810',
#                     'Name': 'Южноафриканских рэндов',
#                     'Nominal': 10,
#                     'NumCode': '710',
#                     'Previous': 56.8963,
#                     'Value': 57.3366}}}

# %% [markdown]
# Теперь данные находятся в словаре и можно легко получать необходимые значения.
#
# Например, по ключу Valute мы можем обратиться к вложенному словарю, который содержит информацию о мировых валютах. Выведем на экран, например, информацию о евро (EUR):

# %%
pprint(currencies["Valute"]["EUR"])  # Выводим на экран информацию о валюте евро
# Out:
# {'CharCode': 'EUR',
#  'ID': 'R01239',
#  'Name': 'Евро',
#  'Nominal': 1,
#  'NumCode': '978',
#  'Previous': 107.4252,
#  'Value': 108.8705}

# %% [markdown]
# ### Задание 3.2
# Повторите запросы, описанные в этом юните, на своём компьютере. Что будет выведено на экран в результате выполнения следующего кода?
#
# ```python
# print(currencies['Valute']['CZK']['Name'])
# ```

# %%
print(currencies["Valute"]["CZK"]["Name"])
# Out:
# Чешских крон

# %% [markdown]
# ## 4. Парсинг сайтов

# %% [markdown]
# ### Получаем содержимое веб-страницы

# %% [markdown]
# Получим HTML-код интересующей нас страницы.
#
# Для этого отправим GET-запрос с помощью библиотеки requests и метода get() и посмотрим на текст ответа на наш запрос (как мы помним, он содержится в атрибуте text):

# %%
url = "https://nplus1.ru/news/2021/10/11/econobel2021"  # Определяем адрес страницы
response = requests.get(url)  # Выполняем GET-запрос
print(response.text)  # Выводим содержимое атрибута text
# Out:
# <!DOCTYPE html>
# <html prefix="og: http://ogp.me/ns#" lang="ru">
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
#     <link rel="preload" href="https://staticn1.nplus1.ru/fonts/AeonikPro/AeonikPro-Regular.woff2" as="font" type="font/woff2" crossorigin />
#     <link rel="preload" href="https://staticn1.nplus1.ru/fonts/Spectral/Spectral-Regular.woff" as="font" type="font/woff2" crossorigin />
#   <link href="/front-build/css/main.css?id=842e64708435127ee441c2e86afffea2" rel="stylesheet">
#   <link href="/front-build/css/app.css?id=92673ebe7185ebc42e29fc7294a4c65f" rel="stylesheet">
#
#
#   <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">
#   <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">
#   <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">
#   <link rel="manifest" href="/site.webmanifest">
#   <link rel="mask-icon" href="/safari-pinned-tab.svg" color="#f26e40">
#   <meta name="msapplication-TileColor" content="#f26e40">
#   <meta name="theme-color" content="#ffffff">
#
#   <link rel="canonical" href="https://nplus1.ru/news/2021/10/11/econobel2021">
#
#   <meta name="yandex-verification" content="8c90b02c84ac3b72"/>
#   <meta name="pmail-verification" content="b419949322895fc9106e24ed01be58ac">
#
#   <!-- Google Tag Manager -->
#
#     <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
#     })(window,document,'script','dataLayer','GTM-PJWMQBQ');</script>
#
#   <!-- End Google Tag Manager -->
#
#     <!-- HuggingCat -->
#         <script async src="https://huggingcat-web.pages.dev/mywidget.js?static=true"></script>
#         <script>
#             (function (c, a) {
#                 var t = (c[a] = c[a] || []);
#                 t.push(["init"]);
#             })(window, "hc");
#         </script>
#     <!-- End HuggingCat -->
#
#     <!-- Ads -->
#         <script src="/front-build/js/modules/prebid.js?id=ddf9cebd6b4c7a66be2ec26a926d5f3c"></script>
#         <script src="/front-build/js/modules/initPrebidAds.js?id=db7f979f79b0f2f3b5f3233e43842936"></script>
#
#         <script src="https://widget.sparrow.ru/js/embed.js"></script>
#     <!-- End Ads -->
#
#
#
#
#
#
#
#   <meta name="description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#
#   <meta property="og:site_name" content="N + 1 — главное издание о науке, технике и технологиях"/>
#   <meta property="og:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей"/>
#   <meta property="og:image" content="https://minio.nplus1.ru/app-images/250227/6301a13e6b36b_cover_share.jpg"/>
#   <meta property="og:url" content="https://nplus1.ru/news/2021/10/11/econobel2021"/>
#   <meta property="og:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. "/>
#   <meta property="og:type" content="article"/>
#
#     <meta itemprop="datePublished" content="2021-10-11"/>
#   <!-- amp page -->
#   <link rel="amphtml" href="https://nplus1.ru/news/2021/10/11/econobel2021/amp">
#
#
#
#   <meta itemprop="datePublished" content="2021-10-11"/>
#
#
#
#       <meta name="mediator_author" content="Илья Ферапонтов"/>
#     <meta name="author" content="Илья Ферапонтов"/>
#
#   <meta name="copyright" content=""/>
#
#       <script type="application/ld+json">
#     {
#       "@context": "https://schema.org",
#       "@type": "NewsArticle",
#       "mainEntityOfPage": {
#         "@type": "WebPage",
#         "@id": "https://nplus1.ru/news/2021/10/11/econobel2021"
#       },
#       "headline": "Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей",
#       "description": "",
#             "image": "https://minio.nplus1.ru/app-images/250227/6301a13e6b36b_cover_share.jpg",
#
#
#
#
#           "author": {
#         "@type": "Person",
#         "name": "Илья Ферапонтов",
#                 "image": "https://minio.nplus1.ru/app-images/793327/f7199286c33e5d744656c65cc770eb5e.jpg",
#                 "url": "https://nplus1.ru/author/ilya-ferapontov"
#         },
#
#         "publisher": {
#       "@type": "Organization",
#       "name": "N+1",
#       "logo": {
#         "@type": "ImageObject",
#         "url": "https://minio.nplus1.ru/app-images/250227/6301a13e6b36b_cover_share.jpg"
#       }
#     },
#     "datePublished": "2021-10-11",
#       "dateModified": "2021-10-11"
#     }
#
#
#
#     </script>
#
#
#
#
#   <meta name="twitter:card" content="summary_large_image">
#   <meta name="twitter:site" content="@nplusodin"/>
#   <meta name="twitter:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей"/>
#   <meta name="twitter:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. "/>
#   <meta name="twitter:image" content="https://minio.nplus1.ru/app-images/250227/6301a13e6b36b_cover_share.jpg"/>
#
#   <link rel='alternate' type='application/rss+xml' title='RSS' href='https://nplus1.ru/rss'>
#
#
#
#
#
#
#
#
#
#
#
#
#
# </head>
# <body class="antialiased">
#
# <!-- Top.Mail.Ru counter -->
#
# <script type="text/javascript">
#
# var tmr = window.tmr || (window._tmr = []);
#
# _tmr.push({id: "3377932", type: "pageView", start: (new Date()).getTime()});
#
# (function (d, w, id) {
#
#   if (d.getElementById(id)) return;
#
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#
# })(document, window, "tmr-code");
#
# </script>
#
# <noscript><div><img src="https://top-fwz1.mail.ru/counter?id=3377932;js=na" style="position:absolute;left:-9999px;" alt="Top.Mail.Ru" /></div></noscript>
#
# <!-- /Top.Mail.Ru counter -->
# <!-- Google Tag Manager (noscript) -->
#   <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-PJWMQBQ"
#   height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
# <div id="appfront" class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray">
#   <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50"
#         data-ref-header
#         ref="headerRef">
#
#       <div id="progressBar" class="absolute bg-main-gray/5 bottom-0 left-0 top-0" style="z-index: -1"></div>
#
#   <div class="border-b border-main-gray h-full">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full"
#          data-ref-header-container
#          ref="headerContainerRef">
#
#       <button aria-label="Go" data-ref-header-menu-btn
#               ref="headerMenuBtnRef"
#               id="topMenuBtn"
#               @click="menuOpen"
#               class="w-7.5 h-7.5">
#         <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
#           <svg class="w-full h-full">
#             <use xlink:href="#n1_cross_menu"></use>
#           </svg>
#         </template>
#         <template v-else>
#           <svg class="w-full h-full">
#             <use xlink:href="#n1_burger"></use>
#           </svg>
#         </template>
#       </button>
#
#       <div>
#                   <a href="/">
#                         <img loading="lazy" src="https://staticn1.nplus1.ru/image-new/logo.svg" height="23" width="57" alt="as">
#                       </a>
#               </div>
#
#       <a href="/search" class="w-7.5 h-7.5">
#         <svg class="w-full h-full">
#           <use xlink:href="#n1_pupa"></use>
#         </svg>
#       </a>
#     </div>
#   </div>
#
#   <nav v-if="isOpenDesktopMenu" id="navMenu" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden"
#        :style="stylesNavDesktop">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#       <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
#
#
#         <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
#
#         <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75"
#            href="https://offline.nplus1.ru/">N + offline</a>
#         <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75"
#            href="https://nplus.pro/">N + production</a>
#       </div>
#       <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
#         <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
#
#                                     <a
#
#                                 href="https://nplus1.ru/about" class="hover:text-main transition-colors duration-75"
#               >
#                 О нас
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/difficult" class="hover:text-main transition-colors duration-75"
#               >
#                 Сложность
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/adv" class="hover:text-main transition-colors duration-75"
#               >
#                 Рекламодателям
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/blog/2022/04/01/samotek" class="hover:text-main transition-colors duration-75"
#               >
#                 Авторам
#               </a>
#
#         </div>
#
#                   <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=946">Игры</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=869">Физика</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=874">Зоология</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=880">Астрономия</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=768">Генетика</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=890">Математика</a>
#                       </div>
#                   <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=871">Космонавтика</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=876">Археология</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=775">Нейронауки</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=767">На мышах</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=771">Звук</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=772">Красота</a>
#                       </div>
#                   <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=778">Научные закрытия</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=918">Когда рассеется дым</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=824">Книжная полка</a>
#                       </div>
#
#       </div>
#       <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
#         <ul class="flex gap-2.5">
#           <li>
#             <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tg"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_vk"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_ok"></use>
#               </svg>
#             </a>
#           </li>
#           <li class="w-12">
#             <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tw"></use>
#               </svg>
#             </a>
#           </li>
#         </ul>
#       </div>
#     </div>
#   </nav>
#
#   <nav v-if="isOpenMobileMenu" id="mobNavMenu" class="relative bg-white max-h-0 n1_top_nav overflow-hidden"
#        :style="stylesNavMobile">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#
#       <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
#                                   <a
#
#                                 href="https://nplus1.ru/about" class="hover:text-main transition-colors duration-75"
#               >
#                 О нас
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/difficult" class="hover:text-main transition-colors duration-75"
#               >
#                 Сложность
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/adv" class="hover:text-main transition-colors duration-75"
#               >
#                 Рекламодателям
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/blog/2022/04/01/samotek" class="hover:text-main transition-colors duration-75"
#               >
#                 Авторам
#               </a>
#                                                                                                                                                                 </div>
#       <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
#
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=946">Игры
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=869">Физика
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=874">Зоология
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=880">Астрономия
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=768">Генетика
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=890">Математика
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=871">Космонавтика
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=876">Археология
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=775">Нейронауки
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=767">На мышах
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=771">Звук
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=772">Красота
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=778">Научные закрытия
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=918">Когда рассеется дым
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=824">Книжная полка
#           </a>
#
#       </div>
#       <div class="max-w-full flex py-5 border-t border-gray-2">
#         <div class="flex gap-x-5 overflow-x-auto">
#
#           <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>
#           <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>
#         </div>
#       </div>
#       <div class="pt-5 pb-10 border-t border-gray-2 text-18">
#         <ul class="flex gap-2.5">
#           <li>
#             <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_tg"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_vk"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_ok"></use>
#               </svg>
#             </a>
#           </li>
#           <li class="w-12">
#             <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_tw"></use>
#               </svg>
#             </a>
#           </li>
#         </ul>
#       </div>
#
#     </div>
#   </nav>
#
# </header>
#
#
#   <app-heading-nav></app-heading-nav>
#
#   <section class="mb-15 md:mb-20">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-7.5 relative"
#          data-heading-wrap>
#
#       <!--tags-->
#
#               <div class="relative flex-wrap col-span-6 md:col-span-12 lg:col-span-2 lg:row-span-3 mt-5 -mb-2.5 lg:-mb-0 lg:mt-10 content-start mr-9">
#           <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
#
#                           <span class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center">
#                 <span class="group-hover:text-main transition-colors duration-75">13:04</span>
#               </span>
#
#             <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                href="/news/2021/10/11">
#               <span class="group-hover:text-main transition-colors duration-75">11.10.21</span>
#             </a>
#             <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                href="/material/difficulty/1">
#               <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#                 <use xlink:href="#n1_star"></use>
#               </svg>
#               <span class="group-hover:text-main transition-colors duration-75">1.1</span>
#             </a>
#
#                                           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                    href="https://nplus1.ru/search?tags=898">
#                   <span class="group-hover:text-main transition-colors duration-75">Экономика</span>
#                 </a>
#
#                                           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                    href="https://nplus1.ru/search?tags=785">
#                   <span class="group-hover:text-main transition-colors duration-75">Нобелевская премия</span>
#                 </a>
#
#           </div>
#           <div class="hidden lg:flex items-center gap-x-2">
#             <a href="https://nplus1.ru/material-print/30917" target="_blank" class="group">
#               <svg class="group-hover:text-main transition-colors duration-75 stroke-current" width="22"
#                    height="30" viewBox="0 0 22 30" fill="none" xmlns="http://www.w3.org/2000/svg">
#                 <rect x="0.5" y="0.5" width="21" height="29"/>
#                 <line x1="4" y1="7.5" x2="18" y2="7.5"/>
#                 <line x1="4" y1="21.5" x2="18" y2="21.5"/>
#                 <line x1="4" y1="14.5" x2="18" y2="14.5"/>
#               </svg>
#             </a>
#
#             <app-copy-material
#                     link="https://nplus1.ru/news/2021/10/11/econobel2021"
#                     type="full-2"
#             ></app-copy-material>
#           </div>
#
#           <div class="w-full flex flex-col mt-5">
#
#
#                       </div>
#
#           <div class="header-bidding-ad-container header-bidding-ad-container--left hidden lg:hidden flex-col mt-5 w-160 h-600">
#             <app-header-bidding-ad
#                 :id="898517"
#                 width="160px"
#                 height="600px"
#                 :close-button="false"
#             ></app-header-bidding-ad>
#           </div>
#         </div>
#
#       <!--dotes menu mobile-->
#       <template v-if="isMobile">
#         <button
#                 @click="openMobileDotsMenu"
#                 class="absolute flex right-5 top-5 z-30 text-main-black" >
#           <svg xmlns="http://www.w3.org/2000/svg" width="30" height="30" viewBox="0 0 30 30" fill="none"
#                class="fill-current">
#             <path fill-rule="evenodd" clip-rule="evenodd"
#                   d="M17 6C17 6.55228 16.5523 7 16 7H15C14.4477 7 14 6.55228 14 6V5C14 4.44772 14.4477 4 15 4H16C16.5523 4 17 4.44772 17 5V6ZM17 23C17 23.5523 16.5523 24 16 24H15C14.4477 24 14 23.5523 14 23V22C14 21.4477 14.4477 21 15 21H16C16.5523 21 17 21.4477 17 22V23ZM14 14.5C14 15.0523 14.4477 15.5 15 15.5H16C16.5523 15.5 17 15.0523 17 14.5V13.5C17 12.9477 16.5523 12.5 16 12.5H15C14.4477 12.5 14 12.9477 14 13.5V14.5Z"/>
#           </svg>
#         </button>
#
#         <div ref="mobileDotsMenuRef"
#              :class="{
#            'transition-transform flex items-center gap-x-7.5 absolute top-0 right-0 w-full px-6 md:px-8 h-20 bg-white z-30 justify-end bg-light-gray':true,
#            '-translate-x-full': !isOpenMobileDotsMenu,
#            '-translate-x-0': isOpenMobileDotsMenu
#            }">
#
#           <app-copy-material
#                   link="https://nplus1.ru/news/2021/10/11/econobel2021"
#                   type="mobile"
#           ></app-copy-material>
#
#           <button aria-label="Go" class="group">
#             <svg class="group-focus:text-main transition-colors duration-75 stroke-current"
#                  xmlns="http://www.w3.org/2000/svg" width="30" height="40" viewBox="0 0 30 40" fill="none">
#               <path d="M14.3303 26.2967L0.5 38.8697V0.5H28.8333V38.8697L15.003 26.2967L14.6667 25.9909L14.3303 26.2967Z"/>
#             </svg>
#           </button>
#
#           <button aria-label="Go" class="group">
#             <svg class="group-focus:text-main transition-colors duration-75 stroke-current"
#                  xmlns="http://www.w3.org/2000/svg" width="30" height="40" viewBox="0 0 30 40" fill="none">
#               <rect x="0.833984" y="0.5" width="28.3333" height="39"/>
#               <line x1="5.66732" y1="10.1665" x2="24.334" y2="10.1665"/>
#               <line x1="5.66732" y1="28.8335" x2="24.334" y2="28.8335"/>
#               <line x1="5.66732" y1="19.5" x2="24.334" y2="19.5"/>
#             </svg>
#           </button>
#
#         </div>
#       </template>
#
#       <!-- main image -->
#             <!--main-->
#
#       <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10">
#         <div class="flex flex-col">
#
#
#           <h1 class="text-34 md:text-42 xl:text-52 break-words mb-6">
#             Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей
#           </h1>
#
#
#
#
#             <div class="text-14 mb-5 sm:mb-12 flex flex-wrap">
#
#
#                 <span class="whitespace-nowrap">
#
#                   <a class="underline" href="/author/ilya-ferapontov">Илья Ферапонтов</a>
#                 </span>
#
#
#
#
#             </div>
#
#           <div data-lmb-0 class="mb-14">
#
#
#
#
#                                                             <BaseGalleryMain :gid="18670"></BaseGalleryMain>
#
#                      <div></div>
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов <a href="https://www.nobelprize.org/" target="_blank">шла</a> на официальном сайте Нобелевской премии.</p></div>
#
#
#                                             <div class="block md:hidden col-span-6 mb-6">
#                             <div class="w-full" data-ref-sidebar></div>
#
#                                                                                                                                         <a
#                                             href="https://nplus1.ru/material/2024/10/28/ozon-soc"
#                                             target="_blank"
#                                             id="adv-banner-link-text"
#                                             data-adv-banner-id="8"
#                                         >
#                                             <picture>
#                                                 <source media="(min-width: 768px)" srcset="https://minio.nplus1.ru/app-images/968786/988b48e8a7667363bf66de078ae08203.png">
#
#                                                 <img
#                                                     class="w-full"
#                                                     src="https://minio.nplus1.ru/app-images/968787/2ba46fb0b05a4d2c0e7de71e5fc75b9d.png"
#                                                     loading="lazy"
#                                                     alt="Ozon — Концентрированный SOC"
#                                                 >
#                                             </picture>
#                                         </a>
#                                                                                                                         </div>
#
#
#
#
#
#
#                                                             <BaseGalleryMain :gid="1381"></BaseGalleryMain>
#
#                      <div></div>
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Премия по экономике, в отличие от Нобелевских премий по физиологии и медицине, физике, химии и литературе, а также премии мира, была учреждена не самим Альфредом Нобелем, а Банком Швеции в 1968 году. Ее размер равен размеру остальных премий.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Лауреаты этого года награждены за их исследования причинно-следственных связей в области социальных наук. В частности, Дэвид Кард из университета Калифорнии в Беркли начиная с 1990-х годов исследовал, как именно на рынок труда влияют изменения минимальных зарплат, уровень иммиграции и образовательный уровень населения. Полученные им результаты, в частности, указывали, что повышение уровня минимальных зарплат не обязательно влечет за собой сокращение количества рабочих мест.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Два других лауреата - Джошуа Ангрист из Массачусетского технологического института и Гвидо Имбенс из Стэнфордского университета исследовали, как можно установить наличие причинно-следственных связей в естественных экспериментах, связанных с поисками отношения между уровнем образования и доходами.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Компания Clarivate, которая составляет списки потенциальных нобелевских лауреатов на основе наукометрических данных, в 2021 году <a href="https://nplus1.ru/blog/2021/09/22/clarivate-prognosis-2021" target="_blank">предположила</a>, что в экономической номинации премию могут присудить Дэвиду Одречу (David Audretsch) и Дэвиду Тису (David Teece) за исследование инноваций.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Кроме того, в списке этого года были Джоэл Мокир (Joel Mokyr), который исследует культурные истоки промышленной революции, а также Кармен Рейнхарт (Carmen Reinhart) и Кеннет Рогофф (Kenneth Rogoff) — авторы гипотезы «90-процентного порога»., согласно которой, когда внешний долг государства достигает 90 процентов от ВВП, скорость роста ВВП падает вдвое.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">В 2020 году премию по экономике присудили Полу Милгрому и Роберту Уилсону за развитие теории аукционов и изобретение новых форматов аукционов. Лауреаты исследовали, как работают аукционы, и разрабатывали новые форматы проведения аукционов для продажи товаров и услуг, которые трудно продавать с помощью традиционных методов. Читайте об их работах в нашем материале <a href="https://nplus1.ru/material/2020/10/13/nobel-econ-2020" target="_blank">«Тонкости молотка»</a>.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">В 2019 году премии памяти Нобеля по экономике были удостоены Абхиджит Банерджи, Эстер Дюфло и Майкл Кремер — «за экспериментальный подход к искоренению глобальной бедности». Подробнее о заслугах лауреатов можно прочесть в нашем материале <a href="https://nplus1.ru/material/2019/10/14/nobeleconomic" target="_blank" title="Link: https://nplus1.ru/material/2019/10/14/nobeleconomic">«Опыты на бедных»</a>. В 2018 года награда была присуждена Уильяму Нордхаусу за «интеграцию изменения климата в долгосрочный макроэкономический анализ» и Полу Ромеру за «интеграцию технологических инноваций в долгосрочный макроэкономический анализ». Об их работах можно прочитать в материале <a href="https://nplus1.ru/material/2018/10/08/econobel-2018" target="_blank">«Почем знания для природы»</a>.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6"><i>Сергей Кузнецов</i></p></div>
#
#
#
#
#                                       </div>
#
#
#           <div class="text-18">
#
#
#
#             <div class="text-20 font-spectral text-main-gray leading-none" v-if="!isMobile">
#               Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.
#             </div>
#
#           </div>
#
#         </div>
#       </div>
#
#       <!--right sidebar-->
#
#       <div class="block col-span-6 md:col-span-4 lg:col-span-3 row-span-3 mt-10">
#             <div class="w-full" data-ref-sidebar></div>
#
#
#                                                             <a
#                             class="hidden md:block"
#                             href="https://nplus1.ru/material/2024/10/28/ozon-soc"
#                             target="_blank"
#                             id="adv-banner-link-sidebar"
#                             data-adv-banner-id="8"
#                         >
#                             <picture>
#                                 <source media="(min-width: 768px)" srcset="https://minio.nplus1.ru/app-images/968786/988b48e8a7667363bf66de078ae08203.png">
#
#                                 <img
#                                     class="w-full"
#                                     src="https://minio.nplus1.ru/app-images/968787/2ba46fb0b05a4d2c0e7de71e5fc75b9d.png"
#                                     loading="lazy"
#                                     alt="Ozon — Концентрированный SOC"
#                                 >
#                             </picture>
#                         </a>
#
#
#                     <div class="header-bidding-ad-container header-bidding-ad-container--right hidden md:hidden flex-col mt-5 w-300 h-600">
#                         <app-header-bidding-ad
#                             :id="898516"
#                             width="300px"
#                             height="600px"
#                             :close-button="false"
#                         ></app-header-bidding-ad>
#                     </div>
#
#
#                   </div>
#     </div>
#   </section>
#
#
#       <section class="mb-9 md:mb-20">
#
#
#   <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-9">
#
#     <!--tags-->
#
#           <div class="flex-wrap col-span-6 md:col-span-12 lg:col-span-2 -mb-2.5 lg:-mb-0 content-start">
#         <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
#
#
#           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#              href="/blog/2023/07/05">
#             <span class="group-hover:text-main transition-colors duration-75">05.07.23</span>
#           </a>
#
#           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#              href="/material/difficulty/1">
#             <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#               <use xlink:href="#n1_star"></use>
#             </svg>
#             <span class="group-hover:text-main transition-colors duration-75">1.1</span>
#           </a>
#
#                                     <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                  href="https://nplus1.ru/search?tags=817">
#                 <span class="group-hover:text-main transition-colors duration-75">История</span>
#               </a>
#                           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                  href="https://nplus1.ru/search?tags=898">
#                 <span class="group-hover:text-main transition-colors duration-75">Экономика</span>
#               </a>
#
#
#         </div>
#         <div class="hidden lg:flex items-center gap-x-2">
#
#
#
#
#
#
#
#
#                       <a href="https://nplus1.ru/material-print/65501" aria-label="Go" class="group">
#               <svg class="group-hover:text-main transition-colors duration-75 stroke-current" width="22" height="30"
#                    viewBox="0 0 22 30" fill="none" xmlns="http://www.w3.org/2000/svg">
#                 <rect x="0.5" y="0.5" width="21" height="29"></rect>
#                 <line x1="4" y1="7.5" x2="18" y2="7.5"></line>
#                 <line x1="4" y1="21.5" x2="18" y2="21.5"></line>
#                 <line x1="4" y1="14.5" x2="18" y2="14.5"></line>
#               </svg>
#             </a>
#
#
#
#
#
#
#                       <app-copy-material
#                     link="https://nplus1.ru/blog/2023/07/05/his-times-his-crimes"
#                     type="full-2"
#             ></app-copy-material>
#
#         </div>
#       </div>
#
#     <!--main image  -->
#
#
#
#     <!--main-->
#
#     <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10 lg:mt-0 ">
#       <div class="flex flex-col">
#
#         <div class="text-34 md:text-42 xl:text-52 break-words">
#           «Уинстон Черчилль: его эпоха, его преступления»
#         </div>
#
#                   <p class="text-36 md:text-44 xl:text-54 font-spectral text-main-gray mb-6">Критический взгляд на фигуру «величайшего британца в истории»</p>
#
#                   <div class="grid grid-cols-6 sm:grid-cols-7 items-center text-14 pt-1.5 sm:pt-6 mb-10 sm:mb-13 gap-y-10 gap-x-5 md:gap-x-9">
#             <div class="col-span-6 sm:col-span-3 gap-x-5 flex items-center">
#                               <a class="shrink-0 w-12 h-12" href="/author/alpina-non-fiksn">
#                   <img src="https://minio.nplus1.ru/app-images/694729/1ccc6e9960399e0551870d97fc98b306.jpg"
#                        loading="lazy"
#                        class="w-full h-full object-cover" alt="Альпина нон-фикшн">
#                 </a>
#                             <a class="text-14 flex flex-col" href="/author/alpina-non-fiksn">
#                 <span class="mb-0.5">
#
#                                     Альпина нон-фикшн
#                 </span>
#                 <span class="font-spectral text-main-gray">Научно-популярное издательство</span>
#               </a>
#             </div>
#             <div class="col-span-6 sm:col-span-3 lg:col-start-5">
#               <p class="font-spectral text-main-gray">Мнение редакции может не совпадать с&nbsp;мнением автора</p>
#             </div>
#           </div>
#
#         <div class="text-14 pt-4 sm:pt-6 mb-10 sm:mb-12 flex flex-wrap">
#
#             <a class="underline whitespace-nowrap"
#                href="/author/alpina-non-fiksn">Альпина нон-фикшн</a>
#
#
#                   </div>
#
#         <div class="n1_material text-18" id="read-next-2">
#           <p class="mb-6">Уинстон Черчилль известен прежде всего как политик и полководец, возглавивший Великобританию в войне с нацизмом. Однако многим он также запомнился как сторонник империализма и воплощение правящего класса, который боролся с рабочими и подавлял всякое инакомыслие. В книге «Уинстон Черчилль: его эпоха, его преступления» (издательство «Альпина нон-фикшн»), переведенной на русский язык Максимом Коробовым, историк Тарик Али рассказывает о неприглядных эпизодах политической карьеры Черчилля, в том числе военных ошибках, допущенных в ходе Первой мировой войны, борьбе с ирландскими националистами и голоде в Бенгалии. Предлагаем вам ознакомиться с фрагментом, посвященным тому, как действия правительства Великобритании привели к крупнейшей забастовке в истории британского рабочего движения.</p>
#         </div>
#
#         <div class="mt-5 md:mt-6 mb-5">
#           <a class="inline-flex justify-center bg-main w-full py-4"
#              href="https://nplus1.ru/blog/2023/07/05/his-times-his-crimes">
#             <span class="text-white text-22 md:text-24">Читать дальше</span>
#           </a>
#         </div>
#
#       </div>
#     </div>
#
#   </div>
# </section>
#
#
#
#
#   <div class="mb-5 w-full overflow-hidden">
#     <app-material-slider-carousel :const-container="constContainer" :const-start-container="constStartContainer">
#   <template v-slot:default="slotProps">
#
#
#   </template>
# </app-material-slider-carousel>
#   </div>
#
#   <div class="exchange-ad-container mb-5">
#         <app-exchange-ad
#             script-url="/front-build/js/modules/initExchangeAds.js?id=d41d8cd98f00b204e9800998ecf8427e"
#             data-key="545b0632c32e67738ab0b6219c3153a6"
#         ></app-exchange-ad>
#   </div>
#
#   <app-typo-modal :width="constContainer" material-id="30917"></app-typo-modal>
#
#
#
#
#   <footer class="mt-auto relative">
#   <app-cookie></app-cookie>
#
#   <div class="bg-main-black pb-15 sm:py-10 md:py-12 xl:py-15">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 sm:gap-x-9">
#       <div class="order-1 col-span-6 sm:col-span-3 lg:col-span-2 mb-12 sm:mb-10">
#         <div>
#           <svg class="n1_footer_logo" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 148 60" fill="none">
#             <path d="M0 60V0H11.6065L36.9417 37.8V0H49.5723V60H37.8804L12.5339 22.2V60H0Z" fill="#F9F9F9"></path>
#             <path d="M75.0234 11.144H85.9471V24.8583H98.9191V35.0583H85.9471V48.8583H75.0234V35.0583H62.1367V24.8583H75.0234V11.144Z"
#                   fill="#F9F9F9"></path>
#             <path d="M136.304 49.5429H147.999V60H111.473V49.5429H124.103V21.8571C123.118 22.0352 122.118 22.1213 121.116 22.1143H111.643V11.9143H119.751C122.823 11.9143 124.274 9.08572 124.274 5.82858V0H136.307L136.304 49.5429Z"
#                   fill="#F9F9F9"></path>
#           </svg>
#         </div>
#       </div>
#       <ul class="order-2 sm:order-3 col-span-6 sm:col-span-3 lg:col-span-2 row-span-2 text-26 sm:text-16 text-light-gray font-spectral font-light mb-10 lg:mb-0 gap-y-1.5 sm:gap-y-4 flex flex-col">
#                               <li>
#               <a target="_blank" href="https://nplus1.ru/about"
#                  class="transition-colors duration-75 hover:text-main">О нас</a>
#             </li>
#                                         <li>
#               <a target="_blank" href="https://nplus1.ru/difficult"
#                  class="transition-colors duration-75 hover:text-main">Сложность</a>
#             </li>
#                                         <li>
#               <a target="_blank" href="https://nplus1.ru/adv"
#                  class="transition-colors duration-75 hover:text-main">Рекламодателям</a>
#             </li>
#                                         <li>
#               <a target="_blank" href="https://nplus1.ru/blog/2022/04/01/samotek"
#                  class="transition-colors duration-75 hover:text-main">Авторам</a>
#             </li>
#                                                                                                                                     </ul>
#       <div class="order-2 col-span-6 sm:col-span-9 lg:col-span-10 mb-10">
#         <h4 class="text-gray-2 text-18 md:text-20 lg:text-26 col-span-10 lg:leading-28">© 2024 N + 1 Интернет-издание / Свидетельство о регистрации СМИ Эл № ФС77-67614</h4>
#       </div>
#       <div class="order-4 col-span-6 sm:col-span-9 lg:col-span-5 lg:row-span-2 mb-10 lg:mb-0">
#         <div class="text-gray-2 text-16"><p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на N&nbsp;+&nbsp;1.</p>
# <p>Все аудиовизуальные произведения являются собственностью своих авторов и&nbsp;правообладателей и&nbsp;используются только в&nbsp;образовательных и&nbsp;информационных целях.</p><p>Если вы&nbsp;являетесь собственником того или иного произведения и&nbsp;не&nbsp;согласны с&nbsp;его размещением на&nbsp;нашем сайте, пожалуйста, напишите на&nbsp;<a href="/cdn-cgi/l/email-protection#abc5c7ebc5dbc7ded89a85d9de"><span class="__cf_email__" data-cfemail="89e7e5c9e7f9e5fcfab8a7fbfc">[email&#160;protected]</span></a></p>
# <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>
# <p>Связь с редакцией: <a href="/cdn-cgi/l/email-protection#ddb4b3bbb29db3adb1a8aeecf3afa8"><span class="__cf_email__" data-cfemail="731a1d151c331d031f0600425d0106">[email&#160;protected]</span></a></p></div>
#       </div>
#       <div class="order-5 col-span-6 sm:col-span-9 sm:col-start-4 lg:col-span-5 text-gray-2 text-16 leading-none flex flex-col">
#
#
#
#
#
#
#
#
#         <a class="underline transition-colors duration-75 hover:text-main inline-block col-span-6 sm:col-span-5 mb-5 font-spectral italic"
#            href="/personal-data-policy">Политика
#           обработки
#           персональных данных пользователей сайта
#         </a>
#
#       </div>
# ...
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_ok"></use>
#               </svg>
#             </a>
#           </li>
#           <li class="w-12">
#             <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tw"></use>
#               </svg>
#             </a>
#           </li>
#         </ul>
#       </div>
#     </div>
#   </div>
#
# </footer>
# </div>
#
#
# <svg id="n1_star" class="stroke-current" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      width="16" height="16"
#      viewBox="3 3 16 16" fill="none">
#   <path d="M11 5V17"/>
#   <path d="M6.75781 6.75781L15.2431 15.2431"/>
#   <path d="M17 11L5 11"/>
#   <path d="M15.2422 6.75781L6.75691 15.2431"/>
# </svg>
# <svg id="n1_person" class="stroke-current" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      viewBox="0 0 50 50" fill="none">
#   <circle cx="25" cy="25" r="24.5"/>
#   <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z"
#         stroke-miterlimit="10"/>
# </svg>
# <svg id="n1_tg" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 50 50"
#      fill="none">
#   <path d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z"
#         class="fill-current"/>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"/>
# </svg>
# <svg id="n1_vk" style="display:block;width:0;height:0" viewBox="0 0 50 50" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <path d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z"
#         class="fill-current"></path>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"></circle>
# </svg>
# <svg id="n1_ok" style="display:block;width:0;height:0" viewBox="0 0 50 50" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <path d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z"
#         class="fill-current"></path>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"></circle>
# </svg>
# <svg id="n1_tw" style="display:block;width:0;height:0" viewBox="0 0 50 50" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <path d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z"
#         class="fill-current"></path>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"></circle>
# </svg>
# <svg id="n1_infinity" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink" width="64px" height="64px" viewBox="0 0 100 100"
#      preserveAspectRatio="xMidYMid">
#   <path fill="none" stroke="#ffffff" stroke-width="5" stroke-dasharray="146.25568908691406 110.33323913574219"
#         d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z"
#         stroke-linecap="round" style="transform:scale(0.8);transform-origin:50px 50px">
#     <animate attributeName="stroke-dashoffset" repeatCount="indefinite" dur="1.3157894736842106s" keyTimes="0;1"
#              values="0;256.58892822265625"></animate>
#   </path>
# </svg>
# <svg id="n1_cross" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 14 14"
#      fill="none">
#   <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9"/>
#   <path d="M13 1L1 13" stroke="#F9F9F9"/>
# </svg>
# <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewBox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
#   <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z"
#         fill="currentColor"></path>
# </svg>
# <svg id="n1_big_star" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 61 61">
#   <path class="fill-current" fill-rule="evenodd" clip-rule="evenodd"
#         d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z"/>
#   <path class="fill-current"
#         d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L32.5405 30.8336L30.7728 29.0658ZM49.2039 10.6347L50.9716 8.86696L49.2039 7.09919L47.4361 8.86696L49.2039 10.6347ZM49.911 11.3418L51.6787 13.1096L53.4465 11.3418L51.6787 9.57407L49.911 11.3418ZM31.4799 29.7729L29.7121 28.0052L25.4443 32.2729H31.4799V29.7729ZM57.5455 29.7729H60.0455V27.2729H57.5455V29.7729ZM57.5455 30.7729V33.2729H60.0455V30.7729H57.5455ZM31.4799 30.7729V28.2729H25.4443L29.7121 32.5407L31.4799 30.7729ZM49.9111 49.2042L51.6789 50.972L53.4466 49.2042L51.6789 47.4364L49.9111 49.2042ZM49.204 49.9113L47.4362 51.6791L49.204 53.4468L50.9718 51.6791L49.204 49.9113ZM30.7728 31.4801L32.5405 29.7123L28.2728 25.4445V31.4801H30.7728ZM30.7728 57.5455V60.0455H33.2728V57.5455H30.7728ZM29.7728 57.5455H27.2728V60.0455H29.7728V57.5455ZM29.7728 31.4801H32.2728V25.4445L28.005 29.7123L29.7728 31.4801ZM11.3415 49.9113L9.57374 51.6791L11.3415 53.4468L13.1093 51.6791L11.3415 49.9113ZM10.6344 49.2042L8.86664 47.4364L7.09887 49.2042L8.86664 50.972L10.6344 49.2042ZM29.0656 30.7729L30.8334 32.5407L35.1012 28.2729H29.0656V30.7729ZM3 30.7729H0.5V33.2729H3V30.7729ZM29.0656 27.2729H3V32.2729H29.0656V27.2729ZM8.86676 13.1096L27.2979 31.5407L30.8334 28.0052L12.4023 9.57407L8.86676 13.1096ZM9.57387 8.86696L8.86676 9.57407L12.4023 13.1096L13.1094 12.4025L9.57387 8.86696ZM31.5405 27.2981L13.1094 8.86696L9.57387 12.4025L28.005 30.8336L31.5405 27.2981ZM27.2728 3V29.0658H32.2728V3H27.2728ZM30.7728 0.5H29.7728V5.5H30.7728V0.5ZM33.2728 29.0658V3H28.2728V29.0658H33.2728ZM32.5405 30.8336L50.9716 12.4025L47.4361 8.86696L29.005 27.2981L32.5405 30.8336ZM47.4361 12.4025L48.1432 13.1096L51.6787 9.57407L50.9716 8.86696L47.4361 12.4025ZM48.1432 9.57407L29.7121 28.0052L33.2476 31.5407L51.6787 13.1096L48.1432 9.57407ZM57.5455 27.2729H31.4799V32.2729H57.5455V27.2729ZM60.0455 30.7729V29.7729H55.0455V30.7729H60.0455ZM31.4799 33.2729H57.5455V28.2729H31.4799V33.2729ZM51.6789 47.4364L33.2476 29.0052L29.7121 32.5407L48.1433 50.972L51.6789 47.4364ZM50.9718 51.6791L51.6789 50.972L48.1433 47.4364L47.4362 48.1435L50.9718 51.6791ZM29.005 33.2478L47.4362 51.6791L50.9718 48.1435L32.5405 29.7123L29.005 33.2478ZM33.2728 57.5455V31.4801H28.2728V57.5455H33.2728ZM29.7728 60.0455H30.7728V55.0455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z"/>
# </svg>
# <svg id="n1_circle_arrow" style="display:block;width:0;height:0" class="stroke-current"
#      xmlns="http://www.w3.org/2000/svg" viewBox="0 0 30 30" fill="none">
#   <rect x="29.5" y="29.5" width="29" height="29" rx="14.5" transform="rotate(-180 29.5 29.5)"/>
#   <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z"/>
# </svg>
# <svg id="n1_circle_arrow_solid" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      viewBox="0 0 30 30" fill="none">
#   <mask id="path-1-inside-1_2694_77554">
#     <path fill-rule="evenodd" clip-rule="evenodd"
#           d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z"/>
#   </mask>
#   <path fill-rule="evenodd" clip-rule="evenodd"
#         d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z"
#         fill="#fff"/>
#   <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z"
#         fill="#fff" mask="url(#path-1-inside-1_2694_77554)"/>
# </svg>
# <svg id="n1_play" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 50 50"
#      fill="none">
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"/>
#   <path d="M18 35V15L36 25L18 35Z" class="stroke-current"/>
# </svg>
# <svg id="n1_pupa" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 23"
#      fill="none">
#   <path fill-rule="evenodd" clip-rule="evenodd"
#         d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z"
#         fill="#32363A"/>
# </svg>
# <svg id="n1_burger" style="display:block;width:0;height:0;" viewBox="0 0 30 30" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <line y1="6.5" x2="30" y2="6.5" stroke="#32363A"/>
#   <line y1="23.5" x2="30" y2="23.5" stroke="#32363A"/>
#   <line y1="15" x2="30" y2="15" stroke="#32363A"/>
# </svg>
# <svg id="n1_cross_menu" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 30 30"
#      fill="none">
#   <path d="M4 4L26 26" stroke="#32363A"/>
#   <path d="M26 4L4 26" stroke="#32363A"/>
# </svg>
# <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" xmlns="http://www.w3.org/2000/svg"
#      version="1.1" viewBox="0 0 752 752">
#   <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z"/>
# </svg>
# <svg id="n1_specials_star"
#   style="display:block;width:0;height:0;fill:none;stroke:white"
#   xmlns="http://www.w3.org/2000/svg"
#   version="1.1" viewBox="0 0 16 16">
#   <path d="M7.99982 2.18188L9.79764 5.77236L13.818 6.35166L10.9089 9.14489L11.5955 13.091L7.99982 11.2269L4.40419 13.091L5.09073 9.14489L2.18164 6.35166L6.202 5.77236L7.99982 2.18188Z" stroke-linecap="round"/>
# </svg>
#
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="/front-build/js/app.js?id=dd5e25d7814af92b9161a324a2c82337"></script>
#
#
#
#
#   <!-- Yandex.Metrika counter 2-->
# <script type="text/javascript" >
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
# </script>
# <noscript>
#   <div>
#     <img src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;" alt="" />
#     <img src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;" alt="" />
#   </div>
# </noscript>
# <!-- /Yandex.Metrika counter -->
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
# </script>
#
#
#   <script>window.yaContextCb = window.yaContextCb || []</script>
#   <script src="https://yandex.ru/ads/system/context.js" async></script>
#
#
#
#
# <script>
# if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
# </script>
#
#
#
#
# </body>
# </html>

# %% [markdown]
# В отличие от предыдущего примера, где ответ возвращался в JSON-формате, мы не можем так просто преобразовать HTML-код в словарь и извлечь необходимую нам информацию.
#
# Для решения таких задач в Python существует специальная библиотека BeautifulSoup, о работе с которой мы поговорим в следующем юните.

# %% [markdown]
# ## 5. Библиотека BeautifulSoup

# %% [markdown]
# Для поиска необходимых нам данных мы будем использовать библиотеку BeautifulSoup, которая позволяет по названию тегов и их атрибутов получать содержащийся в них текст.

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# Ранее мы уже получили содержимое страницы с помощью GET-запроса и сохранили информацию в переменной response, теперь создадим объект BeautifulSoup с именем page, указывая в качестве параметра html.parser.
#
# Для примера получим информацию o title (с англ. заголовок) — это строка, которая отображается на вкладке браузера:

# %%
url = "https://nplus1.ru/news/2021/10/11/econobel2021"  # Определяем адрес страницы
response = requests.get(
    url
)  # Выполняем GET-запрос, содержимое ответа присваивается переменной response
page = BeautifulSoup(
    response.text, "html.parser"
)  # Создаём объект BeautifulSoup, указывая html-парсер
print(page.title)  # Получаем тег title, отображающийся на вкладке браузера
print(
    page.title.text
)  # Выводим текст из полученного тега, который содержится в атрибуте text
# Out:
# <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %% [markdown]
# ### Извлекаем заголовок и время написания статьи

# %% [markdown]
# Предположим, что мы знаем, что в HTML-коде рассматриваемой нами страницы заголовок статьи заключён в тег <`h1`> … <`/h1`> (заголовок первого уровня).
#
# Тогда мы можем получить его текст с помощью метода find() (с англ. найти) объекта BeautifulSoup, передав ему название интересующего нас тега:

# %%
print(
    page.find("h1").text
)  # Применяем метод find() к объекту и выводим результат на экран
# Out:
#             Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %% [markdown]
# Теперь получим данные из него с помощью метода find(), передав название нужного тега:

# %%
print(page.find("span", class_="relative").text)
# Out:
# 13:04

# %% [markdown]
# ### Задание 5.3
#
# Используя инструмент разработчика в браузере, определите, в каком теге лежит большой заголовок на странице в Wikipedia.

# %%
def wiki_header(url):
    response = requests.get(url)
    page = BeautifulSoup(response.text, "html.parser")
    return page.find("h1").text

# %%
wiki_header("https://en.wikipedia.org/wiki/Operating_system")
# Out:
# 'Operating system'

# %% [markdown]
# ### Неуникальные теги: извлекаем текст и дату публикации статьи

# %% [markdown]
# Посмотрим на нашу страницу, используя инструмент разработчика, ещё раз. Можем заметить, что у искомого текста есть свой класс — n1_material text-18

# %%
print(
    page.find("div", class_="n1_material text-18").text
)  # Выводим содержимое атрибута text тега div класса n1_material text-18
# Out:
# Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов шла на официальном сайте Нобелевской премии.

# %% [markdown]
# В данном случае происходит поиск точного строкового значения class атрибута, т. е. выполнение строк кода

# %%
print(page.find("div", class_="n1_material").text)
# Out:
# Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов шла на официальном сайте Нобелевской премии.

# %%
print(page.find("div", class_="n1_material text-18").text)
# Out:
# Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов шла на официальном сайте Нобелевской премии.

# %% [markdown]
# даст одинаковый результат.

# %% [markdown]
# При выполнении строки кода

# %%
print(page.find("div", class_="text-18 n1_material").text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 print(page.find("div", class_="text-18 n1_material").text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# мы получим ошибку, так как такого строкового значения в области поиска нет.
#
# Аналогично получим информации о теге, который содержит дату написания статьи, отображаемую в левом верхнем углу страницы.

# %% [markdown]
# Итак, нам нужен тег `<a>` … `</a>` с классом "relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center". Для поиска достаточно указать в качестве класса "relative", отбросив дополнительные настройки.

# %% [markdown]
# Теперь получим данные из него с помощью уже известного метода find(), передав название нужного тега:

# %%
# Выводим на экран содержимое атрибута text тега a с классом "relative"
print(page.find("a", class_="relative").text)
# Out:
# 11.10.21

# %% [markdown]
# Задача решена — мы извлекли из контента страницы заголовок статьи, опубликованной на странице, дату публикации, а также текст статьи.

# %% [markdown]
# ### Сбор нескольких элементов: собираем все ссылки на странице

# %% [markdown]
# Рассмотрим ещё один сценарий: вы хотите собрать сразу несколько элементов со страницы. Например, представьте, что вы хотите получить названия всех языков программирования, упомянутых на странице в Wikipedia в статье про языки программирования.
#
# Можно заметить, что все названия языков программирования на этой странице связаны ссылками c соответствующими статьями о них. Таким образом, нам необходимо собрать все ссылки на странице. Для ссылок в HTML предусмотрен тег `<a>` … `</a>`. Попробуем использовать find():

# %%
url = "https://en.wikipedia.org/wiki/List_of_programming_languages"  # Задаём адрес ресурса
response = requests.get(url)  # Делаем GET-запрос к ресурсу
page = BeautifulSoup(response.text, "html.parser")  # Создаём объект BeautifulSoup
print(page.find("a"))  # Ищем ссылку по тегу <a> и выводим её на экран
# Out:
# <a class="mw-jump-link" href="#bodyContent">Jump to content</a>

# %% [markdown]
# Мы получили только одну ссылку, хотя на странице их явно больше.
#
# Это происходит, потому что метод find() возвращает только первый подходящий элемент. Если требуется получить больше элементов, необходимо воспользоваться методом find_all() (с англ. найти все):

# %%
links = page.find_all(
    "a"
)  # Ищем все ссылки на странице и сохраняем в переменной links в виде списка
print(len(links))  # Выводим количество найденных ссылок
# Out:
# 950

# %% [markdown]
# Итак, на момент создания этих учебных материалов на странице содержалось 950 ссылок. Посмотрим на некоторые из них:

# %%
print(
    [link.text for link in links[500:510]]
)  # Выводим ссылки с 500 по 509 включительно
# Out:
# ['MAD', 'MAD/I', 'Magik', 'Magma', 'Maple', 'MAPPER', 'MARK-IV', 'Mary', 'MATLAB', 'MASM Microsoft Assembly x86']

# %% [markdown]
# Не все ссылки соответствуют названиям языков программирования — страница содержит также «служебные» ссылки, такие, например, как Jump to navigation (с англ. Перейти к навигации) или Alphabetical (с англ. По алфавиту):

# %%
print([link.text for link in links[0:10]])  # Выводим ссылки с 1 по 9 включительно
# Out:
# ['Jump to content', 'Main page', 'Contents', 'Current events', 'Random article', 'About Wikipedia', 'Contact us', 'Help', 'Learn to edit', 'Community portal']

# %% [markdown]
# ## 6. Работа с API

# %% [markdown]
# Токен

# %% [markdown]
# fc83f2d0fc83f2d0fc83f2d038ffa6c50effc83fc83f2d09bc4adc5aad2da07209726b1

# %% [markdown]
# ### Первые запросы к API

# %% [markdown]
# Чтобы познакомиться с работой API, мы будем получать данные для статистических отчётов произвольной группы, например данные о соотношении мужчин и женщин, статистику географии пользователей и т. п.
#
# Сначала рассмотрим работу API на простом примере, на основе которого работают многие системы.
#
# Сделаем наш первый запрос из браузера.
#
# Перейдите по следующей ниже ссылке в браузере, подставив вместо слова TOKEN ваш персональный сервисный ключ доступа (токен), полученный на предыдущем шаге:

# %% [markdown]
# https://api.vk.com/method/users.get?user_id=1&v=5.95&access_token=fc83f2d0fc83f2d0fc83f2d038ffa6c50effc83fc83f2d09bc4adc5aad2da07209726b1

# %% [markdown]
# Результат:
#
# ```
# {"response":[{"id":1,"first_name":"Павел","last_name":"Дуров",
# "can_access_closed":true,"is_closed":false}]}
# ```

# %% [markdown]
# Итак, мы сделали GET-запрос к API ВКонтакте, который состоит из следующих элементов:
#
# - https://api.vk.com/method — домен и URL запроса API; обычно не меняется;
# - users.get — название метода, который отдаёт определённый отчёт, в нашем случае это метод для получения информации о пользователе;
# - user_id и v — параметры запроса: идентификатор пользователя, о котором хотим получить информацию (в нашем примере мы запрашиваем информацию о первом пользователе), и номер версии API;
# - token — токен, который выдаётся только пользователям, имеющим право просматривать определённые данные, например показания счётчиков Яндекс.Метрики вашего проекта; на все остальные запросы без корректного токена система отвечает отказом.

# %% [markdown]
# Если мы обратимся к документации метода users.get, то увидим, что в ней описано множество других параметров, которые можно получить о пользователе (дата рождения, пол, родной город и другие) — словом, всё то, что мы видим на странице пользователя в интерфейсе или приложении ВКонтакте (конечно, если пользователь их указал).
#
# Добавим к запросу дату рождения и пол (согласно документации, эти параметры надо перечислять в поле fields):

# %% [markdown]
# https://api.vk.com/method/users.get?user_id=1&v=5.95&fields=sex,bdate&access_token=fc83f2d0fc83f2d0fc83f2d038ffa6c50effc83fc83f2d09bc4adc5aad2da07209726b1

# %% [markdown]
# ```
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел",  "last_name":"Дуров","can_access_closed":true,"is_closed":false}]}
# ```

# %% [markdown]
# До этого момента мы делали запросы в браузере — теперь давайте выполним запросы из кода.

# %% [markdown]
# ### Запрос к API из кода

# %%
import requests

token = "fc83f2d0fc83f2d0fc83f2d038ffa6c50effc83fc83f2d09bc4adc5aad2da07209726b1"  # Указываем свой сервисный токен
url = "https://api.vk.com/method/users.get"  # Указываем адрес страницы к которой делаем запрос
params = {
    "user_id": 1,
    "v": 5.95,
    "fields": "sex,bdate",
    "access_token": token,
    "lang": "ru",
}  # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params)  # Отправляем запрос
print(response.text)  # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}

# %% [markdown]
# Мы получили строку в JSON-формате, которую можно преобразовать в словарь с помощью метода json(), после чего можно с лёгкостью обращаться к различным полям.
#
# Словари нагляднее выводить с помощью функции pprint(), которую мы уже использовали ранее:

# %%
from pprint import pprint

pprint(response.json())  # Выводим содержимое словаря, содержащего ответ, на экран
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %% [markdown]
# Как вы видите, по ключу response мы можем получить список, в котором хранятся словари, содержащие информацию о запрошенных нами пользователях. Мы запросили информацию лишь об одном из них, поэтому список содержит только один элемент. Извлечём его:

# %%
user = response.json()["response"][
    0
]  # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user["bdate"])  # Выводим дату рождения первого пользователя на экран
# Out:
# 10.10.1984

# %% [markdown]
# ### Задание 6.1
# Мы вывели на экран дату рождения пользователя. Напишите строку кода, которая выведет на экран имя пользователя:

# %%
print(user['first_name'])
# Out:
# Павел

# %% [markdown]
# Метод users.get() позволяет запрашивать информацию о множестве (до 1 000) пользователей одновременно. Для этого нужно использовать параметр user_ids и передавать id через запятую в строковом формате. Например, чтобы получить информацию о пользователях с id=1, id=2, id=3, необходимо передать значение параметра user_ids='1,2,3'.
#
# Попробуем это сделать:

# %%
ids = ",".join(
    map(str, range(1, 4))
)  # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {
    "user_ids": ids,
    "v": 5.95,
    "fields": "bdate",
    "access_token": token,
    "lang": "ru",
}  # Формируем строку параметров
pprint(
    requests.get(url, params=params).json()
)  # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'bdate': '14.2',
#                'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'is_closed': False,
#                'last_name': ''}]}

# %% [markdown]
# ### Задание 6.2
# Используя API, определите долю женщин (sex=1) среди пользователей с id от 1 до 500. Иногда будут попадаться пользователи, у которых пол не указан (sex=0), — таких пользователей не нужно учитывать в общем числе.
#
# В ответе укажите число, округлив до двух знаков после точки-разделителя, например, 0.55.
#
# Пример: если у нас будет 300 пользователей с sex=1, 100 пользователей с sex=2 и 100 пользователей с sex=0, то в ответе должно быть 0.75.

# %%
ids = ",".join(
    map(str, range(1, 501))
)  # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {
    "user_ids": ids,
    "v": 5.95,
    "fields": "sex, bdate",
    "access_token": token,
    "lang": "ru",
}  # Формируем строку параметров

# %%
response = requests.get(url, params=params).json()["response"]

# %%
response
# Out:
# [{'id': 1, 'bdate': '10.10.1984', 'sex': 2, 'first_name': 'Павел', 'last_name': 'Дуров', 'can_access_closed': True, 'is_closed': False}, {'id': 2, 'bdate': '14.2', 'sex': 1, 'first_name': 'Александра', 'last_name': 'Владимирова', 'can_access_closed': False, 'is_closed': True}, {'id': 3, 'sex': 0, 'deactivated': 'deleted', 'first_name': 'DELETED', 'last_name': '', 'can_access_closed': True, 'is_closed': False}, {'id': 4, 'sex': 0, 'deactivated': 'deleted', 'first_name': 'DELETED', 'last_name': '', 'can_access_closed': True, 'is_closed': False}, {'id': 5, 'bdate': '18.11', 'sex': 2, 'first_name': 'Илья', 'last_name': 'Перекопский', 'can_access_closed': True, 'is_closed': False}, {'id': 6, 'sex': 2, 'first_name': 'Николай', 'last_name': 'Дуров', 'can_access_closed': True, 'is_closed': False}, {'id': 7, 'sex': 2, 'first_name': 'Алексей', 'last_name': 'Кобылянский', 'can_access_closed': False, 'is_closed': True}, {'id': 8, 'sex': 2, 'first_name': 'Аки', 'last_name': 'Сепиашвили', 'can_access_closed': True, 'is_closed': False}, {'id': 9, 'bdate': '1.1.2001', 'sex': 1, 'first_name': 'Настя', 'last_name': 'Васильева', 'can_access_closed': False, 'is_closed': True}, {'id': 10, 'sex': 2, 'first_name': 'Александр', 'last_name': 'Кузнецов', 'can_access_closed': False, 'is_closed': True}, {'id': 11, 'bdate': '18.12', 'sex': 2, 'first_name': 'Михаил', 'last_name': 'Петров', 'can_access_closed': True, 'is_closed': False}, {'id': 12, 'bdate': '28.12', 'sex': 2, 'deactivated': 'deleted', 'first_name': 'DELETED', 'last_name': '', 'can_access_closed': True, 'is_closed': False}, {'id': 13, 'sex': 0, 'deactivated': 'deleted', 'first_name': 'DELETED', 'last_name': '', 'can_access_closed': True, 'is_closed': False}, {'id': 14, 'sex': 2, 'first_name': 'Андрей', 'last_name': 'Городецкий', 'can_access_closed': True, 'is_closed': False}, {'id': 15, 'bdate': '15.2', 'sex': 2, 'first_name': 'Сергей', 'last_name': 'Васильков', 'can_access_closed': True, 'is_closed': False}, {'id': 16, 'sex': 1, 'first_name': 'Виктория', 'last_name': 'Беспалова', 'can_access_closed': False, 'is_closed': True}, {'id': 17, 'bdate': '21.10.1982', 'sex': 2, 'first_name': 'Александр', 'last_name': 'Беспалов', 'can_access_closed': True, 'is_closed': False}, {'id': 18, 'sex': 2, 'first_name': 'Simon', 'last_name': 'Krechmer', 'can_access_closed': True, 'is_closed': False}, {'id': 19, 'bdate': '12.12', 'sex': 1, 'first_name': 'Светочек', 'last_name': 'Аленький', 'can_access_closed': True, 'is_closed': False}, {'id': 20, 'sex': 2, 'first_name': 'Илья', 'last_name': 'Турпиашвили', 'can_access_closed': False, 'is_closed': True}, {'id': 21, 'bdate': '23.7.1985', 'sex': 2, 'first_name': 'Михаил', 'last_name': 'Равдоникас', 'can_access_closed': True, 'is_closed': False}, {'id': 22, 'bdate': '31.1.1986', 'sex': 2, 'first_name': 'Семен', 'last_name': 'Воронин', 'can_access_closed': True, 'is_closed': False}, {'id': 23, 'bdate': '14.11', 'sex': 2, 'first_name': 'Андрей', 'last_name': 'Столбовский', 'can_access_closed': True, 'is_closed': False}, {'id': 24, 'bdate': '11.5.1986', 'sex': 2, 'first_name': 'Рамми', 'last_name': 'Цицуашвили', 'can_access_closed': False, 'is_closed': True}, {'id': 25, 'bdate': '22.3.1984', 'sex': 1, 'first_name': 'Анастасия', 'last_name': 'Ведущенко', 'can_access_closed': False, 'is_closed': True}, {'id': 26, 'sex': 0, 'deactivated': 'deleted', 'first_name': 'DELETED', 'last_name': '', 'can_access_closed': True, 'is_closed': False}, {'id': 27, 'bdate': '9.1', 'sex': 1, 'first_name': 'Юлия', 'last_name': 'Семиколенова', 'can_access_closed': True, 'is_closed': False}, {'id': 28, 'sex': 0, 'deactivated': 'deleted', 'first_name': 'DELETED', 'last_name': '', 'can_access_closed': True, 'is_closed': False}, {'id': 29, 'sex': 0, 'deactivated': 'deleted', 'first_name': 'DELETED', 'last_name': '', 'can_access_closed': True, 'is_closed': False}, {'id': 30, 'sex': 0, 'deactivated': 'deleted', 'first_name': 'DELETED', 'last_name': '', 'can_access_closed': True, 'is_closed': Fa ...

# %%
men = women = 0
for elem in response:
    if elem["sex"] == 2:
        men += 1
    elif elem["sex"] == 1:
        women += 1
    else:
        continue
print(round(women / (men + women), 2))
# Out:
# 0.49

# %% [markdown]
# ### Сбор информации из групп

# %% [markdown]
# Теперь мы научимся считать произвольные метрики групп, собирая данные из API и работая с двумя ограничениями, которые свойственны практически всем системам:
#
# - ограничение на количество вызовов в единицу времени;
# - ограничение на количество выгружаемых строк за один запрос.

# %% [markdown]
# Ограничение на количество запросов в единицу времени сделано для того, чтобы избежать чрезмерной нагрузки на серверы системы. В ряде случаев небольшое количество отчётов можно выгрузить и уложиться в действующий лимит.
#
# Однако второе ограничение не удастся обойти в случае выгрузки больших отчётов. Например, чтобы получить список всех пользователей популярной группы, серверу, возможно, придётся отправить ответ, содержащий миллионы записей.
#
# Давайте рассмотрим, как работать с этими ограничениями на примере выгрузки списка пользователей группы https://vk.com/vk социальной сети ВКонтакте.
#
# Обратимся к документации, чтобы узнать, какие методы нам доступны для групп, — для получения списка пользователей группы доступен метод groups.getMembers.
#
# Согласно документации, обязательным параметром данного метода является group_id — идентификатор, или короткое имя, группы. В нашем случае это vk: https://vk.com/vk. Протестируем, как работает метод в самом простом случае, — получим id участников группы:

# %%
url = "https://api.vk.com/method/groups.getMembers"  # Указываем адрес обращения
params = {
    "group_id": "vk",
    "v": 5.95,
    "access_token": token,
}  # Формируем строку параметров
response = requests.get(url, params=params)  # Посылаем запрос
data = response.json()  # Ответ сохраняем в переменной data в формате словаря
print(data)  # Выводим содержимое переменной data на экран (отображён фрагмент)
# Out:
# {'response': {'count': 13701658, 'items': [6, 19, 47, 54, 79, 177, 198, 212, 219, 243, 296, 345, 353, 421, 431, 450, 467, 485, 510, 550, 619, 640, 690, 702, 721, 804, 809, 832, 834, 847, 900, 905, 907, 914, 930, 943, 952, 958, 966, 976, 997, 1000, 1018, 1023, 1032, 1033, 1039, 1059, 1097, 1131, 1139, 1140, 1159, 1174, 1185, 1188, 1273, 1301, 1333, 1334, 1351, 1381, 1386, 1388, 1406, 1411, 1418, 1432, 1494, 1503, 1531, 1550, 1568, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1650, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 1754, 1796, 1814, 1820, 1829, 1834, 1839, 1840, 1843, 1858, 1863, 1869, 1887, 1889, 1917, 1943, 1947, 1955, 1969, 2019, 2028, 2050, 2051, 2052, 2059, 2077, 2103, 2136, 2150, 2195, 2201, 2230, 2236, 2273, 2281, 2296, 2298, 2376, 2389, 2395, 2403, 2412, 2436, 2456, 2466, 2470, 2484, 2513, 2515, 2539, 2576, 2592, 2601, 2622, 2644, 2654, 2692, 2706, 2745, 2755, 2767, 2787, 2797, 2827, 2858, 2909, 2919, 2922, 2932, 2953, 2962, 2982, 3001, 3006, 3041, 3130, 3135, 3172, 3186, 3203, 3231, 3250, 3254, 3316, 3320, 3321, 3328, 3331, 3332, 3364, 3372, 3373, 3384, 3388, 3402, 3420, 3422, 3427, 3436, 3450, 3458, 3472, 3483, 3486, 3491, 3492, 3520, 3545, 3556, 3581, 3626, 3637, 3646, 3653, 3657, 3658, 3675, 3684, 3690, 3697, 3719, 3786, 3820, 3824, 3836, 3837, 3851, 3863, 3904, 3909, 3938, 3948, 3979, 3994, 4004, 4010, 4023, 4026, 4041, 4047, 4048, 4108, 4130, 4157, 4169, 4189, 4192, 4236, 4262, 4282, 4326, 4378, 4439, 4440, 4447, 4485, 4505, 4521, 4528, 4530, 4537, 4543, 4554, 4558, 4563, 4564, 4583, 4599, 4601, 4640, 4668, 4669, 4670, 4672, 4689, 4693, 4728, 4731, 4748, 4754, 4767, 4769, 4790, 4818, 4828, 4857, 4862, 4866, 4881, 4921, 4923, 4928, 4947, 4981, 5011, 5017, 5073, 5161, 5166, 5183, 5251, 5262, 5273, 5276, 5280, 5286, 5354, 5386, 5387, 5392, 5394, 5399, 5401, 5430, 5432, 5436, 5438, 5472, 5484, 5527, 5546, 5547, 5585, 5590, 5597, 5606, 5615, 5629, 5634, 5665, 5701, 5733, 5768, 5793, 5803, 5819, 5846, 5850, 5896, 5914, 5916, 5932, 5944, 5959, 5965, 5968, 5990, 5991, 5993, 5997, 6000, 6021, 6037, 6046, 6086, 6099, 6107, 6111, 6154, 6161, 6167, 6181, 6186, 6187, 6203, 6240, 6260, 6265, 6293, 6323, 6333, 6339, 6379, 6380, 6390, 6440, 6492, 6520, 6547, 6557, 6564, 6595, 6604, 6627, 6635, 6670, 6683, 6689, 6701, 6703, 6709, 6715, 6797, 6801, 6862, 6960, 6994, 7012, 7040, 7047, 7050, 7052, 7068, 7099, 7112, 7115, 7117, 7126, 7141, 7188, 7200, 7226, 7227, 7286, 7290, 7338, 7360, 7402, 7404, 7408, 7428, 7451, 7481, 7488, 7492, 7500, 7525, 7543, 7547, 7557, 7595, 7615, 7652, 7661, 7725, 7737, 7755, 7768, 7777, 7830, 7847, 7855, 7858, 7860, 7962, 7982, 7998, 8019, 8069, 8080, 8093, 8149, 8151, 8156, 8157, 8166, 8167, 8181, 8182, 8194, 8195, 8201, 8224, 8266, 8273, 8298, 8310, 8321, 8323, 8347, 8348, 8377, 8398, 8418, 8422, 8436, 8443, 8479, 8484, 8485, 8505, 8518, 8536, 8544, 8576, 8610, 8636, 8642, 8656, 8658, 8704, 8718, 8727, 8738, 8752, 8777, 8792, 8813, 8875, 8883, 8909, 8910, 8937, 8959, 9000, 9014, 9016, 9018, 9079, 9095, 9100, 9110, 9111, 9115, 9173, 9187, 9189, 9222, 9246, 9256, 9343, 9352, 9399, 9408, 9412, 9413, 9435, 9444, 9447, 9450, 9459, 9466, 9499, 9532, 9536, 9547, 9556, 9566, 9569, 9571, 9579, 9598, 9699, 9723, 9737, 9741, 9748, 9775, 9778, 9782, 9847, 9894, 9900, 9925, 9954, 9971, 9981, 9993, 10090, 10162, 10217, 10272, 10284, 10286, 10302, 10350, 10351, 10354, 10365, 10366, 10376, 10516, 10518, 10570, 10596, 10607, 10615, 10621, 10639, 10682, 10697, 10741, 10749, 10767, 10811, 10833, 10887, 10919, 10955, 10956, 10961, 10972, 10999, 11027, 11064, 11068, 11081, 11084, 11150, 11187, 11191, 11236, 11243, 11271, 11303, 11420, 11446, 11451, 11483, 11568, 11649, 11723, 11727, 11747, 11754, 11763, 11768, 11782, 11865, 11964, 11983, 11986, 12005, 12029, 12036, 12097, 12133, 12150, 12154, 12159, 12172, 12213, 12252, 12255, 12264, 12316, 12325, 12332, 12345, 12353, 12367, 12407, 12441, 12448, 12454, 12456, 12473, 12477, 12545, 12560, 12570, 12597, 12617, 12637, 12638, 12707, 12716, 12718, 12736, 12748, 12 ...

# %% [markdown]
# По ключу count мы можем получить общее число участников группы, а список по ключу items хранит их id. Посмотрим на него поближе:

# %%
print(len(data["response"]["items"]))  # Выводим на экран количество элементов словаря
# Out:
# 1000

# %% [markdown]
# Мы видим, что всего пользователей в группе больше 11 миллионов, а получили мы только первую тысячу пользователей группы. По информации, указанной в документации о параметре count, это максимум, который может отдать API за один раз.
#
# Для получения следующей тысячи пользователей можно воспользоваться параметром offset (с англ. смещение), который передвинет начало отсчёта. Для выгрузки всех пользователей группы будем в цикле выгружать по 1000 пользователей (count будет всегда равен 1000), увеличивая смещение offset на величину count.
#
# Для тренировки напишем цикл выгрузки первых 20 пользователей со значением count=5. Иными словами, мы будем выгружать по пять пользователей за запрос до тех пор, пока не получим информацию о 20 пользователях.
#
# Давайте выведем на экран первые 20 пользователей из нашей первой попытки получить информацию о 1000 пользователей, чтобы мы могли сверить результат выгрузки из 20 пользователей:

# %%
users_for_checking = data["response"]["items"][
    :20
]  # Загружаем в переменную информацию об id первых 20 пользователей в виде списка
print(users_for_checking)  # Выводим перечень id первых 20 пользователей
# Out:
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 243, 296, 345, 353, 421, 431, 450, 467, 485, 510, 550]

# %% [markdown]
# Теперь используем count и offset, чтобы получить те же id по пять за раз:

# %%
url = "https://api.vk.com/method/groups.getMembers"  # Указываем адрес обращения
count = 5
offset = 0
user_ids = []
max_count = 20
while offset < max_count:
    # Будем выгружать по count=5 пользователей,
    # начиная с того места, где закончили на предыдущей итерации (offset)
    print("Выгружаю {} пользователей с offset = {}".format(count, offset))
    params = {
        "group_id": "vk",
        "v": 5.95,
        "count": count,
        "offset": offset,
        "access_token": token,
    }
    response = requests.get(url, params=params)
    data = response.json()
    user_ids += data["response"]["items"]
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили
    offset += count
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 243, 296, 345, 353, 421, 431, 450, 467, 485, 510, 550]

# %% [markdown]
# Сравним списки, полученные двумя способами:

# %%
print(user_ids == users_for_checking)
# Out:
# True

# %% [markdown]
# ### Ограничение по частоте запросов

# %% [markdown]
# В API часто добавляют ограничение по частоте запросов, чтобы отдельно взятые пользователи слишком сильно не перегружали сервер. Подобное ограничение есть и у ВКонтакте — в документации указано, что можно делать не более трёх запросов в секунду.

# %% [markdown]
# Чтобы не следить за частотой отправки запросов с секундомером в руках, мы можем после каждого запроса делать паузу. В этом случае, даже если код будет выполняться на самом быстром компьютере, мы не нарушим установленное ограничение, так как периодичность отправки запросов будет искусственно замедлена.
#
# Воспользуемся библиотекой time и методом sleep, с помощью которого мы можем добавить паузу, например в 0.5 секунд, после каждого запроса:

# %%
import time

# %%
url = "https://api.vk.com/method/groups.getMembers"  # Указываем адрес страницы, к которой делаем запрос
count = 1000
offset = 0
user_ids = []
while offset < 5000:
    params = {
        "group_id": "vk",
        "v": 5.95,
        "count": count,
        "offset": offset,
        "access_token": token,
    }
    response = requests.get(url, params=params)
    data = response.json()
    user_ids += data["response"]["items"]
    offset += count
    print("Ожидаю 0.5 секунды...")
    time.sleep(0.5)
print("Цикл завершен, offset =", offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %% [markdown]
# ### Лайки, репосты и комментарии

# %% [markdown]
# Через API новостной ленты ВКонтакте мы можем получить информацию о взаимодействии с сообщениями в ленте.
#
# Для примера продолжим работать с группой https://vk.com/vk и рассмотрим последние 100 сообщений в новостной ленте.

# %% [markdown]
# Для получения информации о сообщениях на стене в API ВКонтакте предусмотрен метод wall.get. Применим его:

# %%
url = "https://api.vk.com/method/wall.get"  # Указываем адрес страницы, к которой делаем запрос
params = {
    "domain": "vk",
    "filter": "owner",
    "count": 1000,
    "offset": 0,
    "access_token": token,
    "v": 5.95,
}
response = requests.get(url, params=params)
pprint(response.json())
# Out:
# {'response': {'count': 775,
#               'items': [{'attachments': [{'photo': {'access_key': 'e7c80cdbe1f2054e51',
#                                                     'album_id': -7,
#                                                     'date': 1732184999,
#                                                     'id': 457354500,
#                                                     'orig_photo': {'height': 1177,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu',
#                                                                    'width': 1280},
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1527823,
#                                                     'sizes': [{'height': 120,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=130x120',
#                                                                'width': 130},
#                                                               {'height': 120,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=130x120',
#                                                                'width': 130},
#                                                               {'height': 184,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=200x184',
#                                                                'width': 200},
#                                                               {'height': 294,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=320x294',
#                                                                'width': 320},
#                                                               {'height': 469,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=510x469',
#                                                                'width': 510},
#                                                               {'height': 69,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=75x69',
#                                                                'width': 75},
#                                                               {'height': 1177,
#                                                                'type': 'w',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=1280x1177',
#                                                                'width': 1280},
#                                                               {'height': 555,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=604x555',
#                                                                'width': 604},
#                                                               {'height': 742,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=807x742',
#                                                                'width': 807},
#                                                               {'height': 1177,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=1280x1177',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'b9f878cbb36a9fb36f'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 1821},
#                          'date': 1732186801,
#                          'from_id': -22822305,
#                          'hash': 'DY2LgnT2fzk7eQgGrQ',
#                          'id': 1527823,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 433,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 102},
#                          'text': 'Итоги ВКонтакте за третий квартал 2024 года\n'
#                                  '\n'
#                                  'В третьем квартале средняя месячная '
#                                  'аудитория ВКонтакте выросла на 3,1 млн '
#                                  'пользователей, достигнув 88,1 млн. Платформа '
#                                  'охватывает 87% интернет-аудитории России '
#                                  'ежемесячно.\n'
#                                  '\n'
#                                  'Просмотры на VK Видео увеличились на 48,5% '
#                                  'год к году, а количество скачиваний '
#                                  'приложения превысило 30 млн.\n'
#                                  '\n'
#                                  'ВКонтакте также представила обновлённый '
#                                  'дизайн приложения, навигацию в котором можно '
#                                  'настроить под себя, и VK AdBlogger — '
#                                  'платформу для сотрудничества авторов и '
#                                  'бизнеса.\n'
#                                  '\n'
#                                  'Подробности и итоги всех сервисов VK за '
#                                  'третий квартал 2024 года найдёте тут: '
#                                  'vk.company/ru/press/releases/11912',
#                          'type': 'post',
#                          'views': {'count': 183369}},
#                         {'attachments': [{'photo': {'access_key': '5b06ec4536ed40a2bd',
#                                                     'album_id': -7,
#                                                     'date': 1732001942,
#                                                     'id': 457354304,
#                                                     'orig_photo': {'height': 1080,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun9-17.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu',
#                                                                    'width': 1080},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-17.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-17.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-17.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=200x200',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-17.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=320x320',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-17.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=510x510',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-17.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-17.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-17.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-17.userapi.com/s/v1/ig2/T7CLHponRc_-rvDe230jZjqbLh-1ahpv9x_v7SN9-DQKcJarlJS4OyHxKo0-qMPpacDnEnwnNrPUizN4_d4jgp1e.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=1080x1080',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '69bb31dcb54112bbe8'},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': '7c55b1e32d833d7d57',
#                                                     'album_id': -7,
#                                                     'date': 1732001942,
#                                                     'id': 457354305,
#                                                     'orig_photo': {'height': 1080,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun9-51.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu',
#                                                                    'width': 1080},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-51.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-51.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-51.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=200x200',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-51.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=320x320',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-51.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=510x510',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-51.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-51.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-51.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-51.userapi.com/s/v1/ig2/6c-D4V04Msdx9s5NMfhhZC6uZBxZEoAA9-uOaIartGLJpkNEpIXR0LzMp8EKx_excBhGrOC8YAF_mX62EHMYrl_C.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=1080x1080',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'a370d249028e414d24'},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': '284554c10eb558662c',
#                                                     'album_id': -7,
#                                                     'date': 1732001942,
#                                                     'id': 457354306,
#                                                     'orig_photo': {'height': 1080,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun9-24.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu',
#                                                                    'width': 1080},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-24.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-24.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-24.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=200x200',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-24.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=320x320',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-24.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=510x510',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-24.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-24.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-24.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-24.userapi.com/s/v1/ig2/A_Dhus8Y5T9zffqaW4qPzAj-SoZPJ4QAqNZ8MnwevWoOLw_SaBRt3EX08OzHgW9mzDoCE81IAwHTAQiy_qvOJXJc.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=1080x1080',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '4c5af2611c58acf9ef'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 913},
#                          'date': 1732002300,
#                          'from_id': -22822305,
#                          'hash': 'bVCss2zuaafY0yg5jQ',
#                          'id': 1526639,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 332,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 75},
#                          'text': 'Мы изучили портрет пользователя донатных '
#                                  'сервисов и узнали много интересного.\n'
#                                  '\n'
#                                  'Оказалось, что молодёжь чаще поддерживает '
#                                  'художников и иллюстраторов, а люди старше 25 '
#                                  'лет больше донатят за образовательный '
#                                  'контент.\n'
#                                  '\n'
#                                  'Что мотивирует людей донатить? У мужчин на '
#                                  'первом месте желание поддержать автора, а '
#                                  'женщины больше ценят доступ к эксклюзивным '
#                                  'материалам.\n'
#                                  '\n'
#                                  'Листайте карточки, там ещё больше интересных '
#                                  'фактов! А поддержать своих любимых авторов '
#                                  'вы можете через [vk.com/vkdonut|VK Donut].',
#                          'type': 'post',
#                          'views': {'count': 203054}},
#                         {'attachments': [{'photo': {'access_key': 'f0a039969d30e79eff',
#                                                     'album_id': -7,
#                                                     'date': 1731410798,
#                                                     'id': 457354071,
#                                                     'orig_photo': {'height': 2160,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun9-18.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu',
#                                                                    'width': 2160},
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1524596,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-18.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-18.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=130x130',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-18.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=200x200',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-18.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=320x320',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-18.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=510x510',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-18.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=75x75',
#                                                                'width': 75},
#                                                               {'height': 2160,
#                                                                'type': 'w',
#                                                                'url': 'https://sun9-18.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=2160x2160',
#                                                                'width': 2160},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-18.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=604x604',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-18.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=807x807',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-18.userapi.com/s/v1/ig2/TyxppsysGzLiOCIffMQWZI4bA7TABf1H7UD7w2KKilHYbqv_RPeM2VuE853U-J-GvgNO9q-oi25_sh4hFC7x5OpS.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,2160x2160&from=bu&cs=1280x1280',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '4b8b3f90129918301b'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 1566},
#                          'date': 1731411000,
#                          'from_id': -22822305,
#                          'hash': 'FC7YyHuAwt3EgcuJzw',
#                          'id': 1524596,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 485,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 145},
#                          'text': 'В чатах ВКонтакте появилась папка «Бизнес».\n'
#                                  '\n'
#                                  'Статус доставки товара, уведомления о '
#                                  'кешбэке и подтверждения записи в салон '
#                                  'красоты — теперь все сообщения от компаний '
#                                  'собраны в отдельной папке.\n'
#                                  '\n'
#                                  'В неё поступают уведомления от компаний, '
#                                  'которым пользователь разрешил отправку '
#                                  'сообщений по номеру телефона, а также '
#                                  'сообщения от бизнес-сообществ.\n'
#                                  '\n'
#                                  'Обновление доступно в приложениях ВКонтакте '
#                                  'и VK Мессенджер на всех платформах, а также '
#                                  'в новом интерфейсе мессенджера в веб-версии '
#                                  'ВКонтакте.',
#                          'type': 'post',
#                          'views': {'count': 256279}},
#                         {'attachments': [{'photo': {'access_key': '8a15217cc0b2b3ea4c',
#                                                     'album_id': -7,
#                                                     'date': 1730375201,
#                                                     'id': 457353619,
#                                                     'orig_photo': {'height': 1707,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu',
#                                                                    'width': 2560},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 87,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87',
#                                                                'width': 130},
#                                                               {'height': 87,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87',
#                                                                'width': 130},
#                                                               {'height': 133,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=200x133',
#                                                                'width': 200},
#                                                               {'height': 213,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=320x213',
#                                                                'width': 320},
#                                                               {'height': 340,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=510x340',
#                                                                'width': 510},
#                                                               {'height': 50,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=75x50',
#                                                                'width': 75},
#                                                               {'height': 1707,
#                                                                'type': 'w',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=2560x1707',
#                                                                'width': 2560},
#                                                               {'height': 403,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=604x403',
#                                                                'width': 604},
#                                                               {'height': 538,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=807x538',
#                                                                'width': 807},
#                                                               {'height': 853,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-74.userapi.com/s/v1/ig2/jJPezKNIhE37m7VdaPitz7MNJ5qPcdyCEa5ZVNDxy5UZcSwcivxNfQ1txg38z81LLWd_RvpXbIt2Jz0TZfeZBy41.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=1280x853',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '219508655d4ccbf66b'},
#                                           'type': 'photo'},
#                                          {'photo': {'access_key': '2250588f1d5229d08b',
#                                                     'album_id': -7,
#                                                     'date': 1730375201,
#                                                     'id': 457353620,
#                                                     'orig_photo': {'height': 1707,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu',
#                                                                    'width': 2560},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 87,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-46.userapi.com/s/v1/ig2/7ZwLENZzT_J9Hmjrg2s6SDponK3hbL92b7B56ySaMEycUNgvqDnjwk81Fq8zi6RFvtCrABPzoWNpDQwMr2ySc6Md.jpg?quality=96&as=32x21,48x32,72x48,108x72,160x107,240x160,360x240,480x320,540x360,640x427,720x480,1080x720,1280x853,1440x960,2560x1707&from=bu&cs=130x87',
#                                                                'width': 130},
#                                                               {'height': 87,
#                                                                'type': 'o',
# ...
#                                           'type': 'photo'}],
#                          'comments': {'count': 259},
#                          'date': 1706014803,
#                          'from_id': -22822305,
#                          'hash': 'aO8cz6J8r4uLDvW8xA',
#                          'id': 1456023,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 1183,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 300},
#                          'text': 'За каждой великой нейросетью стоят люди. '
#                                  'Хотите стать одним из них? Тогда '
#                                  'присоединяйтесь к [https://vk.com/crowd|VK '
#                                  'Crowd]!\n'
#                                  '\n'
#                                  'Это программа объединяет энтузиастов, '
#                                  'которые собирают и размечают данные для '
#                                  'обучения нейросетей ВКонтакте и помогают '
#                                  'двигать вперёд технологии, которыми '
#                                  'пользуются миллионы людей.\n'
#                                  '\n'
#                                  'За выполненные задания участники VK Crowd '
#                                  'получают баллы и обменивают их на разные '
#                                  'призы. Например, на iPhone, MacBook и умные '
#                                  'колонки VK Капсула.\n'
#                                  '\n'
#                                  'Чтобы присоединиться к программе, пройдите '
#                                  'вступительный тест: vk.cc/conazP. Давайте '
#                                  'вместе делать нейросети и мир лучше!',
#                          'type': 'post',
#                          'views': {'count': 440343}},
#                         {'attachments': [{'photo': {'access_key': 'd234e1a44b68a6d9a6',
#                                                     'album_id': -7,
#                                                     'date': 1705656100,
#                                                     'id': 457346238,
#                                                     'orig_photo': {'height': 1450,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun9-75.userapi.com/s/v1/ig2/5fYBY7J-EE2Ovj4KnKJbehPb5ewgkgPI3DZVWd61thtDwhChrkPKUhPpw6QvmapxJc4xwPBa6lyXyf_E9_TezS97.jpg?quality=96&as=32x23,48x35,72x52,108x78,160x116,240x174,360x261,480x348,540x391,640x464,720x522,1080x783,1280x928,1440x1044,2000x1450&from=bu',
#                                                                    'width': 2000},
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1455138,
#                                                     'sizes': [{'height': 94,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-75.userapi.com/s/v1/ig2/5fYBY7J-EE2Ovj4KnKJbehPb5ewgkgPI3DZVWd61thtDwhChrkPKUhPpw6QvmapxJc4xwPBa6lyXyf_E9_TezS97.jpg?quality=96&as=32x23,48x35,72x52,108x78,160x116,240x174,360x261,480x348,540x391,640x464,720x522,1080x783,1280x928,1440x1044,2000x1450&from=bu&cs=130x94',
#                                                                'width': 130},
#                                                               {'height': 94,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-75.userapi.com/s/v1/ig2/5fYBY7J-EE2Ovj4KnKJbehPb5ewgkgPI3DZVWd61thtDwhChrkPKUhPpw6QvmapxJc4xwPBa6lyXyf_E9_TezS97.jpg?quality=96&as=32x23,48x35,72x52,108x78,160x116,240x174,360x261,480x348,540x391,640x464,720x522,1080x783,1280x928,1440x1044,2000x1450&from=bu&cs=130x94',
#                                                                'width': 130},
#                                                               {'height': 145,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-75.userapi.com/s/v1/ig2/5fYBY7J-EE2Ovj4KnKJbehPb5ewgkgPI3DZVWd61thtDwhChrkPKUhPpw6QvmapxJc4xwPBa6lyXyf_E9_TezS97.jpg?quality=96&as=32x23,48x35,72x52,108x78,160x116,240x174,360x261,480x348,540x391,640x464,720x522,1080x783,1280x928,1440x1044,2000x1450&from=bu&cs=200x145',
#                                                                'width': 200},
#                                                               {'height': 232,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-75.userapi.com/s/v1/ig2/5fYBY7J-EE2Ovj4KnKJbehPb5ewgkgPI3DZVWd61thtDwhChrkPKUhPpw6QvmapxJc4xwPBa6lyXyf_E9_TezS97.jpg?quality=96&as=32x23,48x35,72x52,108x78,160x116,240x174,360x261,480x348,540x391,640x464,720x522,1080x783,1280x928,1440x1044,2000x1450&from=bu&cs=320x232',
#                                                                'width': 320},
#                                                               {'height': 370,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-75.userapi.com/s/v1/ig2/5fYBY7J-EE2Ovj4KnKJbehPb5ewgkgPI3DZVWd61thtDwhChrkPKUhPpw6QvmapxJc4xwPBa6lyXyf_E9_TezS97.jpg?quality=96&as=32x23,48x35,72x52,108x78,160x116,240x174,360x261,480x348,540x391,640x464,720x522,1080x783,1280x928,1440x1044,2000x1450&from=bu&cs=510x370',
#                                                                'width': 510},
#                                                               {'height': 54,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-75.userapi.com/s/v1/ig2/5fYBY7J-EE2Ovj4KnKJbehPb5ewgkgPI3DZVWd61thtDwhChrkPKUhPpw6QvmapxJc4xwPBa6lyXyf_E9_TezS97.jpg?quality=96&as=32x23,48x35,72x52,108x78,160x116,240x174,360x261,480x348,540x391,640x464,720x522,1080x783,1280x928,1440x1044,2000x1450&from=bu&cs=75x54',
#                                                                'width': 75},
#                                                               {'height': 1450,
#                                                                'type': 'w',
#                                                                'url': 'https://sun9-75.userapi.com/s/v1/ig2/5fYBY7J-EE2Ovj4KnKJbehPb5ewgkgPI3DZVWd61thtDwhChrkPKUhPpw6QvmapxJc4xwPBa6lyXyf_E9_TezS97.jpg?quality=96&as=32x23,48x35,72x52,108x78,160x116,240x174,360x261,480x348,540x391,640x464,720x522,1080x783,1280x928,1440x1044,2000x1450&from=bu&cs=2000x1450',
#                                                                'width': 2000},
#                                                               {'height': 438,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-75.userapi.com/s/v1/ig2/5fYBY7J-EE2Ovj4KnKJbehPb5ewgkgPI3DZVWd61thtDwhChrkPKUhPpw6QvmapxJc4xwPBa6lyXyf_E9_TezS97.jpg?quality=96&as=32x23,48x35,72x52,108x78,160x116,240x174,360x261,480x348,540x391,640x464,720x522,1080x783,1280x928,1440x1044,2000x1450&from=bu&cs=604x438',
#                                                                'width': 604},
#                                                               {'height': 585,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-75.userapi.com/s/v1/ig2/5fYBY7J-EE2Ovj4KnKJbehPb5ewgkgPI3DZVWd61thtDwhChrkPKUhPpw6QvmapxJc4xwPBa6lyXyf_E9_TezS97.jpg?quality=96&as=32x23,48x35,72x52,108x78,160x116,240x174,360x261,480x348,540x391,640x464,720x522,1080x783,1280x928,1440x1044,2000x1450&from=bu&cs=807x585',
#                                                                'width': 807},
#                                                               {'height': 928,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-75.userapi.com/s/v1/ig2/5fYBY7J-EE2Ovj4KnKJbehPb5ewgkgPI3DZVWd61thtDwhChrkPKUhPpw6QvmapxJc4xwPBa6lyXyf_E9_TezS97.jpg?quality=96&as=32x23,48x35,72x52,108x78,160x116,240x174,360x261,480x348,540x391,640x464,720x522,1080x783,1280x928,1440x1044,2000x1450&from=bu&cs=1280x928',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'e1fe2678eed7e29cb3'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 570},
#                          'date': 1705658403,
#                          'from_id': -22822305,
#                          'hash': 'bi0TNz0XKibngW1vzQ',
#                          'id': 1455138,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 3588,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 587},
#                          'text': 'Будьте внимательнее, когда скидываете не те '
#                                  'сообщения в не те чаты!',
#                          'type': 'post',
#                          'views': {'count': 1202931}},
#                         {'attachments': [],
#                          'comments': {'count': 873},
#                          'date': 1705481335,
#                          'from_id': -22822305,
#                          'hash': '2w_GjQPzA8NPadyhCw',
#                          'id': 1454278,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 875,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 201},
#                          'text': 'Какие две аудиозаписи лучше всего описывают '
#                                  'ваш профиль ВКонтакте?\n'
#                                  '\n'
#                                  'Ответы в виде треков принимаем в '
#                                  'комментариях 👇',
#                          'type': 'post',
#                          'views': {'count': 964822}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': 'd51776f9e40e070544',
#                                                     'can_add': 1,
#                                                     'can_dislike': 1,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 391,
#                                                     'date': 1705160174,
#                                                     'description': '',
#                                                     'duration': 63,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=0&type=39&tkn=AnzSG5Dfegzv5UGp2IemLfrPrJ0&fn=vid_w',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=0&type=39&tkn=AnzSG5Dfegzv5UGp2IemLfrPrJ0&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=0&type=39&tkn=AnzSG5Dfegzv5UGp2IemLfrPrJ0&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=0&type=39&tkn=AnzSG5Dfegzv5UGp2IemLfrPrJ0&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=0&type=39&tkn=AnzSG5Dfegzv5UGp2IemLfrPrJ0&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456242525,
#                                                     'local_views': 1705142,
#                                                     'owner_id': -22822305,
#                                                     'photo_1280': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=14&type=39&tkn=0DsLlgIjU9xTxIGXS_qAjxhs8o8&fn=vid_w',
#                                                     'photo_130': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=14&type=39&tkn=0DsLlgIjU9xTxIGXS_qAjxhs8o8&fn=vid_s',
#                                                     'photo_320': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=14&type=39&tkn=0DsLlgIjU9xTxIGXS_qAjxhs8o8&fn=vid_l',
#                                                     'photo_800': 'https://i.mycdn.me/getVideoPreview?id=5873937812168&idx=14&type=39&tkn=0DsLlgIjU9xTxIGXS_qAjxhs8o8&fn=vid_x',
#                                                     'response_type': 'full',
#                                                     'should_stretch': False,
#                                                     'title': 'Video by '
#                                                              'ВКонтакте',
#                                                     'track_code': 'video_9291647fHntingiTxNpMI-goF4-tSqxPLEXZ_40HFi7_iKT4Ps0vWnycD_TH3Eog608Uupt4mH0Zd-zw-mZ6Qv-ZicoM9R1oT1PFVAkXgOwiiCI',
#                                                     'views': 1705142,
#                                                     'width': 1080}}],
#                          'comments': {'count': 389},
#                          'date': 1705161602,
#                          'from_id': -22822305,
#                          'hash': 'zHC60fQ3puc9u5vc1Q',
#                          'id': 1453687,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 1656,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 208},
#                          'text': 'На дворе старый Новый год — отличный повод, '
#                                  'чтобы послушать новогодние поздравления от '
#                                  'пользователей ВКонтакте, нашей команды и '
#                                  'звёзд.\n'
#                                  '\n'
#                                  'Всех с Новым годом ещё раз!',
#                          'type': 'post',
#                          'views': {'count': 2353166}}]}}

# %% [markdown]
# Посмотрим на количество результатов:

# %%
len(response.json()["response"]["items"])
## 100
# Out:
# 100

# %% [markdown]
# Посмотрим на информацию об отдельном сообщении:

# %%
response.json()["response"]["items"][0]
# Out:
# {'inner_type': 'wall_wallpost', 'comments': {'count': 1821}, 'marked_as_ads': 0, 'hash': 'DY2LgnT2fzk7eQgGrQ', 'type': 'post', 'push_subscription': {'is_subscribed': False}, 'attachments': [{'type': 'photo', 'photo': {'album_id': -7, 'date': 1732184999, 'id': 457354500, 'owner_id': -22822305, 'access_key': 'e7c80cdbe1f2054e51', 'post_id': 1527823, 'sizes': [{'height': 120, 'type': 'm', 'width': 130, 'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=130x120'}, {'height': 120, 'type': 'o', 'width': 130, 'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=130x120'}, {'height': 184, 'type': 'p', 'width': 200, 'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=200x184'}, {'height': 294, 'type': 'q', 'width': 320, 'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=320x294'}, {'height': 469, 'type': 'r', 'width': 510, 'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=510x469'}, {'height': 69, 'type': 's', 'width': 75, 'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=75x69'}, {'height': 1177, 'type': 'w', 'width': 1280, 'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=1280x1177'}, {'height': 555, 'type': 'x', 'width': 604, 'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=604x555'}, {'height': 742, 'type': 'y', 'width': 807, 'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=807x742'}, {'height': 1177, 'type': 'z', 'width': 1280, 'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu&cs=1280x1177'}], 'text': '', 'user_id': 100, 'web_view_token': 'b9f878cbb36a9fb36f', 'orig_photo': {'height': 1177, 'type': 'base', 'url': 'https://sun9-36.userapi.com/s/v1/ig2/x-afxfZaFGoc9TpyG0eiYrZNWanW3cBkL013Ug8b4XYJPxSq0ghrey88NjliIsPypx483q5Q10e1M1zbGF7LQFZp.jpg?quality=96&as=32x29,48x44,72x66,108x99,160x147,240x221,360x331,480x441,540x497,640x588,720x662,1080x993,1280x1177&from=bu', 'width': 1280}}}], 'date': 1732186801, 'from_id': -22822305, 'id': 1527823, 'likes': {'c ...

# %% [markdown]
# В полях comments, likes и reposts содержится статистика по взаимодействию с сообщением пользователей (на момент получения информации) — число комментариев, лайков и репостов.
#
# Давайте соберём итоговую статистику для последних десяти непустых сообщений в словарь stats. В качестве ключа будем использовать начало сообщения (если начало сообщения пустое, то информацию о таком сообщении проигнорируем), в качестве значения — список с тремя интересующими нас метриками и временем публикации (комментарии, лайки, репосты, дата публикации):

# %%
stats = {}
count_post = 0  # Счётчик «непустых» сообщений
for record in response.json()["response"]["items"][:]:
    title = record["text"][:30]
    if title:
        stats[title] = [
            record["comments"]["count"],
            record["likes"]["count"],
            record["reposts"]["count"],
            record["date"],
        ]
        count_post += 1
    if count_post < 10:
        continue
    else:
        break
pprint(stats)
# Out:
# {'VK Музыка обновилась! Что ново': [495, 838, 245, 1728310195],
#  'В чатах ВКонтакте появилась па': [1566, 485, 145, 1731411000],
#  'Итоги ВКонтакте за третий квар': [1821, 433, 102, 1732186801],
#  'Мы изучили портрет пользовател': [913, 332, 75, 1732002300],
#  'Новая программа монетизации от': [823, 1071, 362, 1727083149],
#  'Обновился VK Мессенджер в веб-': [494, 837, 341, 1726748100],
#  'Представляем VK AdBlogger — но': [162, 468, 181, 1726654200],
#  'Сегодня ВКонтакте исполнилось ': [647, 1785, 275, 1728560919],
#  'Спешим поделиться крайне милым': [2267, 3503, 699, 1730375700],
#  'Что можно успеть за 60 секунд?': [436, 1782, 195, 1726757657]}

# %% [markdown]
# ## 7. Как настроить регулярную выгрузку данных

# %% [markdown]
# ### Как настроить автоматический запуск

# %% [markdown]
# Во всех операционных системах есть встроенные средства запуска программ по расписанию. Однако можно задать расписание запуска необходимых вам функций на языке Python внутри скрипта.
#
# Исполняемый по расписанию код часто называют задачей (англ. task). Для планирования задач в Python есть несколько библиотек, среди которых — популярный и простой в использовании модуль schedule (c англ. расписание). Он позволяет запускать код как с определённым интервалом, так и в заданное время.
#
# Модуль schedule не входит в стандартную библиотеку Python, поэтому его необходимо установить:

# %%
import schedule # Импортируем модуль schedule

# %% [markdown]
# ### Постановка задачи

# %% [markdown]
# Рассмотрим вариант автоматического запуска простой функции, которая выводит на экран короткое сообщение:

# %%
def task():
    print("Hello! I am a task!")
    return

# %% [markdown]
# Предположим, что мы хотим, чтобы функция запускалась через определённые интервалы времени, а именно каждые 15 минут.
#
# Для запуска задачи через определённые интервалы времени в модуле schedule используется метод every(), который получает в качестве единственного аргумента число, указывающее, как часто следует запускать код.
#
# Далее вызывается метод, определяющий единицы измерения промежутков времени, через которые будет выполняться функция. В нашем примере это минуты. Вот как будет выглядеть итоговый код:

# %%
schedule.every(15).minutes.do(task)
# Out:
# Every 15 minutes do task() (last run: [never], next run: 2024-11-27 22:12:09)

# %% [markdown]
# Если бы мы хотели запускать задачу, например, каждый час, то могли бы написать:

# %%
schedule.every(1).hour.do(task)
# Out:
# Every 1 hour do task() (last run: [never], next run: 2024-11-27 22:57:32)

# %% [markdown]
# ### Выполнение функции

# %% [markdown]
# После того как мы создали нашу функцию и определились со временем её запуска, мы можем запустить наш менеджер расписания (schedule). Для этого надо создать бесконечный цикл. Да-да, именно так, ведь скрипт должен выполняться постоянно, чтобы постоянно проверять, не пришло ли время снова выполнить задачу.
#
# Внутри цикла мы будем вызывать особый метод run_pending() для объекта schedule, который будет проверять, нет ли задачи, которую пора выполнить.
#
# После вызова метода run_pending() нужно будет сделать небольшую паузу, после которой можно будет снова проверять, не пришло ли время для выполнения какой-либо функции.
#
# Давайте напишем этот код.
#
# Для создания паузы мы будем использовать метод sleep из модуля time, поэтому наш код начнётся с импорта данного модуля:

# %%
import time

while True:
    schedule.run_pending()
    time.sleep(1)

# %% [markdown]
# Всё готово — теперь можно сохранить файл и выполнить код.
#
# Вот какой код в итоге получился:

# %%
def task():
    print("Hello! I am a task!")
    return


schedule.every(15).minutes.do(task)

while True:
    schedule.run_pending()
    time.sleep(1)

# %% [markdown]
# Этот код будет каждую секунду проверять, не надо ли выполнить какую-то задачу, и раз в 15 минут будет выводить на экран фразу: "Hello! I am a task!" Вывод сообщения будет повторяться до тех пор, пока вы не остановите выполнение скрипта.
